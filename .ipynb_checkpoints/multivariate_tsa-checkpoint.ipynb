# %% [markdown]
# ## Multivariate timeseries analysis
#
# Again we work with 2NE1 dataset. As by nature our dataset is univariate, we I need to first build the following dataset and extract features like mean, std, difference between the current value with 1, 2 and 3 previous days.
#
#                                          Features                                                          target
# -----------------------------------------------------------------------------------------------------     -------
# vat(t=-3)   vat(t=-2)   vat(t=-1)  mean  std   vat(t)-vat(t=-3)   vat(t)-vat(t=-2)   vat(t)-vat(t=-1)      vat(t)

# %%
import math
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# from keras.models import Sequential
# from keras.layers.recurrent import LSTM
# from keras.layers.core import Dense, Activation, Dropout
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from sklearn.utils import shuffle

# %%
df = pd.read_csv('DF_2NE1.CSV')
df['date_idx'] = pd.to_datetime(df['date_idx'], infer_datetime_format=True)

# %%
df.head()
# Out:
#    2NE1_zh.wikipedia.org_all-access_spider   date_idx
# 0                                       18 2015-07-01
# 1                                       11 2015-07-02
# 2                                        5 2015-07-03
# 3                                       13 2015-07-04
# 4                                       14 2015-07-05

# %%
window_size = 3
data = []
target = []
for i in range(len(df) - window_size - 1):
    data.append(df[i:i + window_size]['2NE1_zh.wikipedia.org_all-access_spider'])
    target.append(df.loc[i+window_size]['2NE1_zh.wikipedia.org_all-access_spider'] )

# %%
data[:5]
# Out:
# [0    18
#  1    11
#  2     5
#  Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#  1    11
#  2     5
#  3    13
#  Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#  2     5
#  3    13
#  4    14
#  Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#  3    13
#  4    14
#  5     9
#  Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#  4    14
#  5     9
#  6     9
#  Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64]

# %%
np.array(data)
# Out:
# array([[18, 11,  5],
#        [11,  5, 13],
#        [ 5, 13, 14],
#        ...,
#        [26, 14, 20],
#        [14, 20, 22],
#        [20, 22, 19]], dtype=int64)

# %%
target[:5]
# Out:
# [13, 14, 9, 9, 22]

# %%
type(data)
# Out:
# list

# %%
len(data)
# Out:
# 546

# %%
len(target)
# Out:
# 546

# %%
[item for item in zip(data, target)]
# Out:
# [(0    18
#   1    11
#   2     5
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   13),
#  (1    11
#   2     5
#   3    13
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   14),
#  (2     5
#   3    13
#   4    14
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   9),
#  (3    13
#   4    14
#   5     9
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   9),
#  (4    14
#   5     9
#   6     9
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   22),
#  (5     9
#   6     9
#   7    22
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   26),
#  (6     9
#   7    22
#   8    26
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   24),
#  (7    22
#   8    26
#   9    24
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   19),
#  (8     26
#   9     24
#   10    19
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   10),
#  (9     24
#   10    19
#   11    10
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   14),
#  (10    19
#   11    10
#   12    14
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   15),
#  (11    10
#   12    14
#   13    15
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   8),
#  (12    14
#   13    15
#   14     8
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   16),
#  (13    15
#   14     8
#   15    16
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   8),
#  (14     8
#   15    16
#   16     8
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   8),
#  (15    16
#   16     8
#   17     8
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   16),
#  (16     8
#   17     8
#   18    16
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   7),
#  (17     8
#   18    16
#   19     7
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   11),
#  (18    16
#   19     7
#   20    11
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   10),
#  (19     7
#   20    11
#   21    10
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   20),
#  (20    11
#   21    10
#   22    20
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   18),
#  (21    10
#   22    20
#   23    18
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   15),
#  (22    20
#   23    18
#   24    15
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   14),
#  (23    18
#   24    15
#   25    14
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   49),
#  (24    15
#   25    14
#   26    49
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   10),
#  (25    14
#   26    49
#   27    10
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   16),
#  (26    49
#   27    10
#   28    16
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   18),
#  (27    10
#   28    16
#   29    18
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   8),
#  (28    16
#   29    18
#   30     8
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   5),
#  (29    18
#   30     8
#   31     5
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   9),
#  (30    8
#   31    5
#   32    9
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   7),
#  (31    5
#   32    9
#   33    7
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   13),
#  (32     9
#   33     7
#   34    13
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   9),
#  (33     7
#   34    13
#   35     9
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   7),
#  (34    13
#   35     9
#   36     7
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   4),
#  (35    9
#   36    7
#   37    4
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   11),
#  (36     7
#   37     4
#   38    11
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   10),
#  (37     4
#   38    11
#   39    10
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   5),
#  (38    11
#   39    10
#   40     5
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   9),
#  (39    10
#   40     5
#   41     9
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   9),
#  (40    5
#   41    9
#   42    9
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   9),
#  (41    9
#   42    9
#   43    9
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   9),
#  (42    9
#   43    9
#   44    9
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   13),
#  (43     9
#   44     9
#   45    13
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   4),
#  (44     9
#   45    13
#   46     4
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   15),
#  (45    13
#   46     4
#   47    15
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   25),
#  (46     4
#   47    15
#   48    25
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   9),
#  (47    15
#   48    25
#   49     9
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   5),
#  (48    25
#   49     9
#   50     5
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   6),
#  (49    9
#   50    5
#   51    6
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   20),
#  (50     5
#   51     6
#   52    20
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   3),
#  (51     6
#   52    20
#   53     3
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   14),
#  (52    20
#   53     3
#   54    14
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   46),
#  (53     3
#   54    14
#   55    46
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   5),
#  (54    14
#   55    46
#   56     5
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   5),
#  (55    46
#   56     5
#   57     5
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   13),
#  (56     5
#   57     5
#   58    13
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   4),
#  (57     5
#   58    13
#   59     4
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   9),
#  (58    13
#   59     4
#   60     9
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   10),
#  (59     4
#   60     9
#   61    10
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   9),
#  (60     9
#   61    10
#   62     9
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   11),
#  (61    10
#   62     9
#   63    11
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   11),
#  (62     9
#   63    11
#   64    11
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   11),
#  (63    11
#   64    11
#   65    11
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   9),
#  (64    11
#   65    11
#   66     9
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   15),
#  (65    11
#   66     9
#   67    15
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   5),
#  (66     9
#   67    15
#   68     5
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   10),
#  (67    15
#   68     5
#   69    10
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   7),
#  (68     5
#   69    10
#   70     7
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   4),
#  (69    10
#   70     7
#   71     4
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   8),
#  (70    7
#   71    4
#   72    8
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   9),
#  (71    4
#   72    8
#   73    9
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   10),
#  (72     8
#   73     9
#   74    10
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   6),
#  (73     9
#   74    10
#   75     6
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   13),
#  (74    10
#   75     6
#   76    13
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   16),
#  (75     6
#   76    13
#   77    16
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   6),
#  (76    13
#   77    16
#   78     6
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   24),
#  (77    16
#   78     6
#   79    24
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   9),
#  (78     6
#   79    24
#   80     9
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   11),
#  (79    24
#   80     9
#   81    11
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   12),
#  (80     9
#   81    11
#   82    12
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   8),
#  (81    11
#   82    12
#   83     8
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   14),
#  (82    12
#   83     8
#   84    14
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   6),
#  (83     8
#   84    14
#   85     6
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   6),
#  (84    14
#   85     6
#   86     6
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   11),
#  (85     6
#   86     6
#   87    11
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   14),
#  (86     6
#   87    11
#   88    14
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   6),
#  (87    11
#   88    14
#   89     6
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   10),
#  (88    14
#   89     6
#   90    10
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   20),
#  (89     6
#   90    10
#   91    20
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   7),
#  (90    10
#   91    20
#   92     7
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   15),
#  (91    20
#   92     7
#   93    15
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   8),
#  (92     7
#   93    15
#   94     8
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   15),
#  (93    15
#   94     8
#   95    15
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   5),
#  (94     8
#   95    15
#   96     5
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   8),
#  (95    15
#   96     5
#   97     8
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   8),
#  (96    5
#   97    8
#   98    8
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   5),
#  (97    8
#   98    8
#   99    5
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   11),
#  (98      8
#   99      5
#   100    11
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   165),
#  (99       5
#   100     11
#   101    165
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   34),
#  (100     11
#   101    165
#   102     34
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   6),
#  (101    165
#   102     34
#   103      6
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   13),
#  (102    34
#   103     6
#   104    13
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   8),
#  (103     6
#   104    13
#   105     8
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   9),
#  (104    13
#   105     8
#   106     9
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   11),
#  (105     8
#   106     9
#   107    11
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   26),
#  (106     9
#   107    11
#   108    26
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   18),
#  (107    11
#   108    26
#   109    18
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   3),
#  (108    26
#   109    18
#   110     3
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   5),
#  (109    18
#   110     3
#   111     5
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   12),
#  (110     3
#   111     5
#   112    12
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   6),
#  (111     5
#   112    12
#   113     6
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   16),
#  (112    12
#   113     6
#   114    16
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   19),
#  (113     6
#   114    16
#   115    19
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   9),
#  (114    16
#   115    19
#   116     9
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   10),
#  (115    19
#   116     9
#   117    10
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   11),
#  (116     9
#   117    10
#   118    11
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   11),
#  (117    10
#   118    11
#   119    11
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   7),
#  (118    11
#   119    11
#   120     7
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   9),
#  (119    11
#   120     7
#   121     9
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   10),
#  (120     7
#   121     9
#   122    10
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   24),
#  (121     9
#   122    10
#   123    24
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   6),
#  (122    10
#   123    24
#   124     6
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   6),
#  (123    24
#   124     6
#   125     6
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   8),
#  (124    6
#   125    6
#   126    8
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   16),
#  (125     6
#   126     8
#   127    16
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   13),
#  (126     8
#   127    16
#   128    13
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   10),
#  (127    16
#   128    13
#   129    10
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   10),
#  (128    13
#   129    10
#   130    10
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   6),
#  (129    10
#   130    10
#   131     6
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   5),
#  (130    10
#   131     6
#   132     5
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   20),
#  (131     6
#   132     5
#   133    20
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   6),
#  (132     5
#   133    20
#   134     6
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   47),
#  (133    20
#   134     6
#   135    47
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   9),
#  (134     6
#   135    47
#   136     9
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   9),
#  (135    47
#   136     9
#   137     9
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   12),
#  (136     9
#   137     9
#   138    12
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   11),
#  (137     9
#   138    12
#   139    11
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   17),
#  (138    12
#   139    11
#   140    17
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   15),
#  (139    11
#   140    17
#   141    15
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   14),
#  (140    17
#   141    15
#   142    14
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   11),
#  (141    15
#   142    14
#   143    11
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   97),
#  (142    14
#   143    11
#   144    97
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   11),
#  (143    11
#   144    97
#   145    11
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   12),
#  (144    97
#   145    11
#   146    12
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   11),
#  (145    11
#   146    12
#   147    11
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   14),
#  (146    12
#   147    11
#   148    14
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   15),
#  (147    11
#   148    14
#   149    15
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   12),
#  (148    14
#   149    15
#   150    12
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   104),
#  (149     15
#   150     12
#   151    104
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   5),
#  (150     12
#   151    104
#   152      5
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   22),
#  (151    104
#   152      5
#   153     22
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   45),
#  (152     5
#   153    22
#   154    45
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   75),
#  (153    22
#   154    45
#   155    75
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   29),
#  (154    45
#   155    75
#   156    29
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   34),
#  (155    75
#   156    29
#   157    34
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   20),
#  (156    29
#   157    34
#   158    20
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   12),
#  (157    34
#   158    20
#   159    12
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   25),
#  (158    20
#   159    12
#   160    25
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   9),
#  (159    12
#   160    25
#   161     9
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   62),
#  (160    25
#   161     9
#   162    62
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   20),
#  (161     9
#   162    62
#   163    20
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   19),
#  (162    62
#   163    20
#   164    19
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   8),
#  (163    20
#   164    19
#   165     8
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   23),
#  (164    19
#   165     8
#   166    23
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   13),
#  (165     8
#   166    23
#   167    13
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   16),
#  (166    23
#   167    13
#   168    16
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   34),
#  (167    13
#   168    16
#   169    34
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   36),
#  (168    16
#   169    34
#   170    36
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   11),
#  (169    34
#   170    36
#   171    11
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   18),
#  (170    36
#   171    11
#   172    18
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   12),
#  (171    11
#   172    18
#   173    12
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   24),
#  (172    18
#   173    12
#   174    24
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   30),
#  (173    12
#   174    24
#   175    30
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   27),
#  (174    24
#   175    30
#   176    27
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   44),
#  (175    30
#   176    27
#   177    44
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   35),
#  (176    27
#   177    44
#   178    35
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   53),
#  (177    44
#   178    35
#   179    53
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   11),
#  (178    35
#   179    53
#   180    11
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   26),
#  (179    53
#   180    11
#   181    26
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   13),
#  (180    11
#   181    26
#   182    13
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   18),
#  (181    26
#   182    13
#   183    18
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   9),
#  (182    13
#   183    18
#   184     9
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   16),
#  (183    18
#   184     9
#   185    16
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   6),
#  (184     9
#   185    16
#   186     6
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   19),
#  (185    16
#   186     6
#   187    19
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   20),
#  (186     6
#   187    19
#   188    20
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   19),
#  (187    19
#   188    20
#   189    19
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   22),
#  (188    20
#   189    19
#   190    22
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   30),
#  (189    19
#   190    22
#   191    30
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   14),
#  (190    22
#   191    30
#   192    14
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   16),
#  (191    30
#   192    14
#   193    16
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   22),
#  (192    14
#   193    16
#   194    22
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   15),
#  (193    16
#   194    22
#   195    15
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   15),
#  (194    22
#   195    15
#   196    15
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   26),
#  (195    15
#   196    15
#   197    26
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   16),
#  (196    15
#   197    26
#   198    16
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   13),
#  (197    26
#   198    16
#   199    13
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   27),
#  (198    16
#   199    13
#   200    27
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   18),
#  (199    13
#   200    27
#   201    18
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   13),
#  (200    27
#   201    18
#   202    13
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   32),
#  (201    18
#   202    13
#   203    32
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   31),
#  (202    13
#   203    32
#   204    31
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   16),
#  (203    32
#   204    31
#   205    16
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   38),
#  (204    31
#   205    16
#   206    38
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   18),
#  (205    16
#   206    38
#   207    18
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   9),
#  (206    38
#   207    18
#   208     9
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   14),
#  (207    18
#   208     9
#   209    14
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   10),
#  (208     9
#   209    14
#   210    10
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   24),
#  (209    14
#   210    10
#   211    24
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   8),
#  (210    10
#   211    24
#   212     8
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   15),
#  (211    24
#   212     8
#   213    15
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   18),
#  (212     8
#   213    15
#   214    18
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   10),
#  (213    15
#   214    18
#   215    10
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   23),
#  (214    18
#   215    10
#   216    23
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   17),
#  (215    10
#   216    23
#   217    17
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   11),
#  (216    23
#   217    17
#   218    11
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   26),
#  (217    17
#   218    11
#   219    26
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   14),
#  (218    11
#   219    26
#   220    14
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   8),
#  (219    26
#   220    14
#   221     8
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   12),
#  (220    14
#   221     8
#   222    12
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   9),
#  (221     8
#   222    12
#   223     9
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   11),
#  (222    12
#   223     9
#   224    11
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   34),
#  (223     9
#   224    11
#   225    34
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   17),
#  (224    11
#   225    34
#   226    17
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   29),
#  (225    34
#   226    17
#   227    29
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   11),
#  (226    17
#   227    29
#   228    11
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   9),
#  (227    29
#   228    11
#   229     9
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   14),
#  (228    11
#   229     9
#   230    14
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   21),
#  (229     9
#   230    14
#   231    21
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   12),
#  (230    14
#   231    21
#   232    12
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   11),
#  (231    21
#   232    12
#   233    11
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   13),
#  (232    12
#   233    11
#   234    13
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   11),
#  (233    11
#   234    13
#   235    11
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   13),
#  (234    13
#   235    11
#   236    13
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   16),
#  (235    11
#   236    13
#   237    16
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   13),
#  (236    13
#   237    16
#   238    13
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   19),
#  (237    16
#   238    13
#   239    19
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   21),
#  (238    13
#   239    19
#   240    21
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   14),
#  (239    19
#   240    21
#   241    14
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   11),
#  (240    21
#   241    14
#   242    11
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   35),
#  (241    14
#   242    11
#   243    35
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   18),
#  (242    11
#   243    35
#   244    18
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   42),
#  (243    35
#   244    18
#   245    42
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   15),
#  (244    18
#   245    42
#   246    15
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   5),
#  (245    42
#   246    15
#   247     5
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   21),
#  (246    15
#   247     5
#   248    21
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   56),
#  (247     5
#   248    21
#   249    56
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   9),
#  (248    21
#   249    56
#   250     9
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   20),
#  (249    56
#   250     9
#   251    20
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   17),
#  (250     9
#   251    20
#   252    17
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   18),
#  (251    20
#   252    17
#   253    18
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   8),
#  (252    17
#   253    18
#   254     8
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   9),
#  (253    18
#   254     8
#   255     9
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   17),
#  (254     8
#   255     9
#   256    17
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   9),
#  (255     9
#   256    17
#   257     9
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   10),
#  (256    17
#   257     9
#   258    10
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   14),
#  (257     9
#   258    10
#   259    14
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   17),
#  (258    10
#   259    14
#   260    17
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   6),
#  (259    14
#   260    17
#   261     6
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   18),
#  (260    17
#   261     6
#   262    18
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   13),
#  (261     6
#   262    18
#   263    13
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   11),
#  (262    18
#   263    13
#   264    11
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   12),
#  (263    13
#   264    11
#   265    12
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   11),
#  (264    11
#   265    12
#   266    11
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   8),
#  (265    12
#   266    11
#   267     8
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   15),
#  (266    11
#   267     8
#   268    15
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   11),
#  (267     8
#   268    15
#   269    11
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   20),
#  (268    15
#   269    11
#   270    20
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   59),
#  (269    11
#   270    20
#   271    59
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   11),
#  (270    20
#   271    59
#   272    11
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   18),
#  (271    59
#   272    11
#   273    18
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   17),
#  (272    11
#   273    18
#   274    17
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   12),
#  (273    18
#   274    17
#   275    12
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   14),
#  (274    17
#   275    12
#   276    14
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   13),
#  (275    12
#   276    14
#   277    13
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   9),
#  (276    14
#   277    13
#   278     9
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   490),
#  (277     13
#   278      9
#   279    490
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   189),
#  (278      9
#   279    490
#   280    189
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   102),
#  (279    490
#   280    189
#   281    102
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   38),
#  (280    189
#   281    102
#   282     38
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   126),
#  (281    102
#   282     38
#   283    126
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   71),
#  (282     38
#   283    126
#   284     71
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   21),
#  (283    126
#   284     71
#   285     21
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   57),
#  (284    71
#   285    21
#   286    57
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   79),
#  (285    21
#   286    57
#   287    79
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   17),
#  (286    57
#   287    79
#   288    17
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   17),
#  (287    79
#   288    17
#   289    17
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   23),
#  (288    17
#   289    17
#   290    23
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   16),
#  (289    17
#   290    23
#   291    16
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   23),
#  (290    23
#   291    16
#   292    23
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   18),
#  (291    16
#   292    23
#   293    18
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   22),
#  (292    23
#   293    18
#   294    22
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   44),
#  (293    18
#   294    22
#   295    44
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   6),
#  (294    22
#   295    44
#   296     6
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   31),
#  (295    44
#   296     6
#   297    31
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   17),
#  (296     6
#   297    31
#   298    17
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   25),
#  (297    31
#   298    17
#   299    25
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   40),
#  (298    17
#   299    25
#   300    40
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   19),
#  (299    25
#   300    40
#   301    19
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   15),
#  (300    40
#   301    19
#   302    15
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   15),
#  (301    19
#   302    15
#   303    15
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   29),
#  (302    15
#   303    15
#   304    29
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   18),
#  (303    15
#   304    29
#   305    18
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   16),
#  (304    29
#   305    18
#   306    16
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   13),
#  (305    18
#   306    16
#   307    13
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   20),
#  (306    16
#   307    13
#   308    20
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   22),
#  (307    13
#   308    20
#   309    22
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   19),
#  (308    20
#   309    22
#   310    19
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   11),
#  (309    22
#   310    19
#   311    11
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   50),
#  (310    19
#   311    11
#   312    50
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   22),
#  (311    11
#   312    50
#   313    22
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   39),
#  (312    50
#   313    22
#   314    39
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   23),
#  (313    22
#   314    39
#   315    23
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   21),
#  (314    39
#   315    23
#   316    21
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   23),
#  (315    23
#   316    21
#   317    23
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   22),
#  (316    21
#   317    23
#   318    22
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   16),
#  (317    23
#   318    22
#   319    16
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   19),
#  (318    22
#   319    16
#   320    19
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   35),
#  (319    16
#   320    19
#   321    35
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   16),
#  (320    19
#   321    35
#   322    16
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   12),
#  (321    35
#   322    16
#   323    12
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   15),
#  (322    16
#   323    12
#   324    15
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   13),
#  (323    12
#   324    15
#   325    13
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   14),
#  (324    15
#   325    13
#   326    14
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   10),
#  (325    13
#   326    14
#   327    10
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   21),
#  (326    14
#   327    10
#   328    21
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   20),
#  (327    10
#   328    21
#   329    20
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   19),
#  (328    21
#   329    20
#   330    19
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   14),
#  (329    20
#   330    19
#   331    14
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   12),
#  (330    19
#   331    14
#   332    12
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   15),
#  (331    14
#   332    12
#   333    15
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   17),
#  (332    12
#   333    15
#   334    17
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   16),
#  (333    15
#   334    17
#   335    16
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   21),
#  (334    17
#   335    16
#   336    21
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   27),
#  (335    16
#   336    21
#   337    27
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   13),
#  (336    21
#   337    27
#   338    13
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   11),
#  (337    27
#   338    13
#   339    11
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   15),
#  (338    13
#   339    11
#   340    15
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   14),
#  (339    11
#   340    15
#   341    14
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   18),
#  (340    15
#   341    14
#   342    18
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   18),
#  (341    14
#   342    18
#   343    18
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   10),
#  (342    18
#   343    18
#   344    10
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   11),
#  (343    18
#   344    10
#   345    11
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   14),
#  (344    10
#   345    11
#   346    14
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   18),
#  (345    11
#   346    14
#   347    18
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   14),
#  (346    14
#   347    18
#   348    14
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   13),
#  (347    18
#   348    14
#   349    13
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   17),
#  (348    14
#   349    13
#   350    17
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   15),
#  (349    13
#   350    17
#   351    15
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   14),
#  (350    17
#   351    15
#   352    14
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   234),
#  (351     15
#   352     14
#   353    234
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   8),
#  (352     14
#   353    234
#   354      8
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   62),
#  (353    234
#   354      8
#   355     62
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   26),
#  (354     8
#   355    62
#   356    26
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   22),
#  (355    62
#   356    26
#   357    22
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   8),
#  (356    26
#   357    22
#   358     8
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   22),
#  (357    22
#   358     8
#   359    22
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   15),
#  (358     8
#   359    22
#   360    15
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   69),
#  (359    22
#   360    15
#   361    69
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   11),
#  (360    15
#   361    69
#   362    11
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   18),
#  (361    69
#   362    11
#   363    18
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   23),
#  (362    11
#   363    18
#   364    23
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   12),
#  (363    18
#   364    23
#   365    12
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   20),
#  (364    23
#   365    12
#   366    20
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   17),
#  (365    12
#   366    20
#   367    17
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   15),
#  (366    20
#   367    17
#   368    15
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   16),
#  (367    17
#   368    15
#   369    16
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   18),
#  (368    15
#   369    16
#   370    18
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   21),
#  (369    16
#   370    18
#   371    21
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   15),
#  (370    18
#   371    21
#   372    15
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   30),
#  (371    21
#   372    15
#   373    30
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   115),
#  (372     15
#   373     30
#   374    115
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   56),
#  (373     30
#   374    115
#   375     56
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   45),
#  (374    115
#   375     56
#   376     45
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   17),
#  (375    56
#   376    45
#   377    17
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   18),
#  (376    45
#   377    17
#   378    18
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   15),
#  (377    17
#   378    18
#   379    15
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   18),
#  (378    18
#   379    15
#   380    18
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   14),
#  (379    15
#   380    18
#   381    14
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   15),
#  (380    18
#   381    14
#   382    15
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   15),
#  (381    14
#   382    15
#   383    15
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   24),
#  (382    15
#   383    15
#   384    24
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   22),
#  (383    15
#   384    24
#   385    22
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   18),
#  (384    24
#   385    22
#   386    18
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   30),
#  (385    22
#   386    18
#   387    30
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   12),
#  (386    18
#   387    30
#   388    12
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   13),
#  (387    30
#   388    12
#   389    13
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   18),
#  (388    12
#   389    13
#   390    18
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   17),
#  (389    13
#   390    18
#   391    17
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   31),
#  (390    18
#   391    17
#   392    31
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   26),
#  (391    17
#   392    31
#   393    26
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   29),
#  (392    31
#   393    26
#   394    29
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   12),
#  (393    26
#   394    29
#   395    12
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   19),
#  (394    29
#   395    12
#   396    19
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   19),
#  (395    12
#   396    19
#   397    19
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   57),
#  (396    19
#   397    19
#   398    57
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   17),
#  (397    19
#   398    57
#   399    17
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   20),
#  (398    57
#   399    17
#   400    20
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   49),
#  (399    17
#   400    20
#   401    49
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   10),
#  (400    20
#   401    49
#   402    10
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   19),
#  (401    49
#   402    10
#   403    19
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   26),
#  (402    10
#   403    19
#   404    26
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   41),
#  (403    19
#   404    26
#   405    41
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   23),
#  (404    26
#   405    41
#   406    23
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   30),
#  (405    41
#   406    23
#   407    30
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   55),
#  (406    23
#   407    30
#   408    55
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   17),
#  (407    30
#   408    55
#   409    17
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   24),
#  (408    55
#   409    17
#   410    24
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   14),
#  (409    17
#   410    24
#   411    14
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   12),
#  (410    24
#   411    14
#   412    12
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   49),
#  (411    14
#   412    12
#   413    49
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   42),
#  (412    12
#   413    49
#   414    42
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   37),
#  (413    49
#   414    42
#   415    37
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   13),
#  (414    42
#   415    37
#   416    13
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   30),
#  (415    37
#   416    13
#   417    30
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   20),
#  (416    13
#   417    30
#   418    20
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   33),
#  (417    30
#   418    20
#   419    33
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   20),
#  (418    20
#   419    33
#   420    20
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   14),
#  (419    33
#   420    20
#   421    14
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   40),
#  (420    20
#   421    14
#   422    40
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   15),
#  (421    14
#   422    40
#   423    15
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   18),
#  (422    40
#   423    15
#   424    18
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   26),
#  (423    15
#   424    18
#   425    26
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   8),
#  (424    18
#   425    26
#   426     8
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   25),
#  (425    26
#   426     8
#   427    25
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   21),
#  (426     8
#   427    25
#   428    21
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   20),
#  (427    25
#   428    21
#   429    20
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   25),
#  (428    21
#   429    20
#   430    25
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   19),
#  (429    20
#   430    25
#   431    19
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   23),
#  (430    25
#   431    19
#   432    23
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   18),
#  (431    19
#   432    23
#   433    18
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   19),
#  (432    23
#   433    18
#   434    19
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   18),
#  (433    18
#   434    19
#   435    18
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   55),
#  (434    19
#   435    18
#   436    55
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   16),
#  (435    18
#   436    55
#   437    16
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   65),
#  (436    55
#   437    16
#   438    65
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   11),
#  (437    16
#   438    65
#   439    11
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   11),
#  (438    65
#   439    11
#   440    11
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   13),
#  (439    11
#   440    11
#   441    13
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   20),
#  (440    11
#   441    13
#   442    20
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   21),
#  (441    13
#   442    20
#   443    21
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   13),
#  (442    20
#   443    21
#   444    13
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   24),
#  (443    21
#   444    13
#   445    24
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   20),
#  (444    13
#   445    24
#   446    20
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   13),
#  (445    24
#   446    20
#   447    13
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   32),
#  (446    20
#   447    13
#   448    32
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   16),
#  (447    13
#   448    32
#   449    16
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   10),
#  (448    32
#   449    16
#   450    10
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   13),
#  (449    16
#   450    10
#   451    13
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   44),
#  (450    10
#   451    13
#   452    44
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   17),
#  (451    13
#   452    44
#   453    17
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   13),
#  (452    44
#   453    17
#   454    13
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   72),
#  (453    17
#   454    13
#   455    72
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   40),
#  (454    13
#   455    72
#   456    40
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   19),
#  (455    72
#   456    40
#   457    19
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   14),
#  (456    40
#   457    19
#   458    14
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   13),
#  (457    19
#   458    14
#   459    13
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   12),
#  (458    14
#   459    13
#   460    12
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   14),
#  (459    13
#   460    12
#   461    14
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   10),
#  (460    12
#   461    14
#   462    10
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   26),
#  (461    14
#   462    10
#   463    26
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   13),
#  (462    10
#   463    26
#   464    13
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   22),
#  (463    26
#   464    13
#   465    22
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   14),
#  (464    13
#   465    22
#   466    14
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   23),
#  (465    22
#   466    14
#   467    23
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   12),
#  (466    14
#   467    23
#   468    12
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   8),
#  (467    23
#   468    12
#   469     8
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   50),
#  (468    12
#   469     8
#   470    50
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   13),
#  (469     8
#   470    50
#   471    13
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   10),
#  (470    50
#   471    13
#   472    10
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   16),
#  (471    13
#   472    10
#   473    16
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   14),
#  (472    10
#   473    16
#   474    14
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   10),
#  (473    16
#   474    14
#   475    10
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   24),
#  (474    14
#   475    10
#   476    24
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   10),
#  (475    10
#   476    24
#   477    10
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   20),
#  (476    24
#   477    10
#   478    20
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   10),
#  (477    10
#   478    20
#   479    10
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   26),
#  (478    20
#   479    10
#   480    26
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   25),
#  (479    10
#   480    26
#   481    25
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   16),
#  (480    26
#   481    25
#   482    16
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   19),
#  (481    25
#   482    16
#   483    19
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   20),
#  (482    16
#   483    19
#   484    20
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   12),
#  (483    19
#   484    20
#   485    12
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   19),
#  (484    20
#   485    12
#   486    19
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   50),
#  (485    12
#   486    19
#   487    50
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   16),
#  (486    19
#   487    50
#   488    16
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   30),
#  (487    50
#   488    16
#   489    30
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   18),
#  (488    16
#   489    30
#   490    18
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   25),
#  (489    30
#   490    18
#   491    25
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   14),
#  (490    18
#   491    25
#   492    14
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   20),
#  (491    25
#   492    14
#   493    20
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   8),
#  (492    14
#   493    20
#   494     8
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   67),
#  (493    20
#   494     8
#   495    67
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   13),
#  (494     8
#   495    67
#   496    13
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   41),
#  (495    67
#   496    13
#   497    41
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   10),
#  (496    13
#   497    41
#   498    10
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   21),
#  (497    41
#   498    10
#   499    21
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   13),
#  (498    10
#   499    21
#   500    13
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   8),
#  (499    21
#   500    13
#   501     8
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   15),
#  (500    13
#   501     8
#   502    15
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   14),
#  (501     8
#   502    15
#   503    14
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   12),
#  (502    15
#   503    14
#   504    12
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   6),
#  (503    14
#   504    12
#   505     6
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   11),
#  (504    12
#   505     6
#   506    11
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   10),
#  (505     6
#   506    11
#   507    10
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   42),
#  (506    11
#   507    10
#   508    42
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   21),
#  (507    10
#   508    42
#   509    21
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   24),
#  (508    42
#   509    21
#   510    24
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   14),
#  (509    21
#   510    24
#   511    14
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   11),
#  (510    24
#   511    14
#   512    11
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   204),
#  (511     14
#   512     11
#   513    204
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   14),
#  (512     11
#   513    204
#   514     14
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   45),
#  (513    204
#   514     14
#   515     45
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   33),
#  (514    14
#   515    45
#   516    33
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   28),
#  (515    45
#   516    33
#   517    28
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   18),
#  (516    33
#   517    28
#   518    18
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   14),
#  (517    28
#   518    18
#   519    14
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   47),
#  (518    18
#   519    14
#   520    47
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   15),
#  (519    14
#   520    47
#   521    15
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   14),
#  (520    47
#   521    15
#   522    14
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   18),
#  (521    15
#   522    14
#   523    18
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   20),
#  (522    14
#   523    18
#   524    20
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   14),
#  (523    18
#   524    20
#   525    14
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   16),
#  (524    20
#   525    14
#   526    16
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   14),
#  (525    14
#   526    16
#   527    14
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   20),
#  (526    16
#   527    14
#   528    20
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   60),
#  (527    14
#   528    20
#   529    60
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   22),
#  (528    20
#   529    60
#   530    22
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   15),
#  (529    60
#   530    22
#   531    15
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   17),
#  (530    22
#   531    15
#   532    17
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   19),
#  (531    15
#   532    17
#   533    19
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   18),
#  (532    17
#   533    19
#   534    18
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   21),
#  (533    19
#   534    18
#   535    21
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   21),
#  (534    18
#   535    21
#   536    21
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   47),
#  (535    21
#   536    21
#   537    47
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   65),
#  (536    21
#   537    47
#   538    65
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   17),
#  (537    47
#   538    65
#   539    17
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   32),
#  (538    65
#   539    17
#   540    32
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   63),
#  (539    17
#   540    32
#   541    63
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   15),
#  (540    32
#   541    63
#   542    15
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   26),
#  (541    63
#   542    15
#   543    26
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   14),
#  (542    15
#   543    26
#   544    14
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   20),
#  (543    26
#   544    14
#   545    20
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   22),
#  (544    14
#   545    20
#   546    22
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   19),
#  (545    20
#   546    22
#   547    19
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   18)]

# %%
dict1 = {'features': data,
        'target': target}
# TypeError: unhashable type: 'list'

# %%
dict1
# Out:
# {'features': [0    18
#   1    11
#   2     5
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   1    11
#   2     5
#   3    13
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   2     5
#   3    13
#   4    14
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   3    13
#   4    14
#   5     9
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   4    14
#   5     9
#   6     9
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   5     9
#   6     9
#   7    22
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   6     9
#   7    22
#   8    26
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   7    22
#   8    26
#   9    24
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   8     26
#   9     24
#   10    19
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   9     24
#   10    19
#   11    10
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   10    19
#   11    10
#   12    14
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   11    10
#   12    14
#   13    15
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   12    14
#   13    15
#   14     8
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   13    15
#   14     8
#   15    16
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   14     8
#   15    16
#   16     8
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   15    16
#   16     8
#   17     8
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   16     8
#   17     8
#   18    16
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   17     8
#   18    16
#   19     7
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   18    16
#   19     7
#   20    11
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   19     7
#   20    11
#   21    10
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   20    11
#   21    10
#   22    20
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   21    10
#   22    20
#   23    18
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   22    20
#   23    18
#   24    15
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   23    18
#   24    15
#   25    14
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   24    15
#   25    14
#   26    49
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   25    14
#   26    49
#   27    10
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   26    49
#   27    10
#   28    16
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   27    10
#   28    16
#   29    18
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   28    16
#   29    18
#   30     8
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   29    18
#   30     8
#   31     5
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   30    8
#   31    5
#   32    9
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   31    5
#   32    9
#   33    7
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   32     9
#   33     7
#   34    13
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   33     7
#   34    13
#   35     9
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   34    13
#   35     9
#   36     7
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   35    9
#   36    7
#   37    4
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   36     7
#   37     4
#   38    11
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   37     4
#   38    11
#   39    10
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   38    11
#   39    10
#   40     5
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   39    10
#   40     5
#   41     9
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   40    5
#   41    9
#   42    9
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   41    9
#   42    9
#   43    9
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   42    9
#   43    9
#   44    9
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   43     9
#   44     9
#   45    13
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   44     9
#   45    13
#   46     4
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   45    13
#   46     4
#   47    15
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   46     4
#   47    15
#   48    25
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   47    15
#   48    25
#   49     9
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   48    25
#   49     9
#   50     5
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   49    9
#   50    5
#   51    6
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   50     5
#   51     6
#   52    20
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   51     6
#   52    20
#   53     3
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   52    20
#   53     3
#   54    14
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   53     3
#   54    14
#   55    46
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   54    14
#   55    46
#   56     5
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   55    46
#   56     5
#   57     5
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   56     5
#   57     5
#   58    13
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   57     5
#   58    13
#   59     4
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   58    13
#   59     4
#   60     9
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   59     4
#   60     9
#   61    10
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   60     9
#   61    10
#   62     9
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   61    10
#   62     9
#   63    11
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   62     9
#   63    11
#   64    11
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   63    11
#   64    11
#   65    11
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   64    11
#   65    11
#   66     9
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   65    11
#   66     9
#   67    15
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   66     9
#   67    15
#   68     5
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   67    15
#   68     5
#   69    10
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   68     5
#   69    10
#   70     7
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   69    10
#   70     7
#   71     4
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   70    7
#   71    4
#   72    8
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   71    4
#   72    8
#   73    9
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   72     8
#   73     9
#   74    10
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   73     9
#   74    10
#   75     6
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   74    10
#   75     6
#   76    13
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   75     6
#   76    13
#   77    16
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   76    13
#   77    16
#   78     6
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   77    16
#   78     6
#   79    24
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   78     6
#   79    24
#   80     9
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   79    24
#   80     9
#   81    11
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   80     9
#   81    11
#   82    12
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   81    11
#   82    12
#   83     8
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   82    12
#   83     8
#   84    14
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   83     8
#   84    14
#   85     6
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   84    14
#   85     6
#   86     6
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   85     6
#   86     6
#   87    11
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   86     6
#   87    11
#   88    14
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   87    11
#   88    14
#   89     6
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   88    14
#   89     6
#   90    10
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   89     6
#   90    10
#   91    20
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   90    10
#   91    20
#   92     7
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   91    20
#   92     7
#   93    15
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   92     7
#   93    15
#   94     8
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   93    15
#   94     8
#   95    15
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   94     8
#   95    15
#   96     5
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   95    15
#   96     5
#   97     8
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   96    5
#   97    8
#   98    8
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   97    8
#   98    8
#   99    5
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   98      8
#   99      5
#   100    11
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   99       5
#   100     11
#   101    165
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   100     11
#   101    165
#   102     34
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   101    165
#   102     34
#   103      6
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   102    34
#   103     6
#   104    13
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   103     6
#   104    13
#   105     8
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   104    13
#   105     8
#   106     9
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   105     8
#   106     9
#   107    11
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   106     9
#   107    11
#   108    26
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   107    11
#   108    26
#   109    18
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   108    26
#   109    18
#   110     3
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   109    18
#   110     3
#   111     5
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   110     3
#   111     5
#   112    12
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   111     5
#   112    12
#   113     6
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   112    12
#   113     6
#   114    16
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   113     6
#   114    16
#   115    19
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   114    16
#   115    19
#   116     9
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   115    19
#   116     9
#   117    10
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   116     9
#   117    10
#   118    11
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   117    10
#   118    11
#   119    11
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   118    11
#   119    11
#   120     7
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   119    11
#   120     7
#   121     9
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   120     7
#   121     9
#   122    10
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   121     9
#   122    10
#   123    24
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   122    10
#   123    24
#   124     6
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   123    24
#   124     6
#   125     6
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   124    6
#   125    6
#   126    8
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   125     6
#   126     8
#   127    16
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   126     8
#   127    16
#   128    13
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   127    16
#   128    13
#   129    10
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   128    13
#   129    10
#   130    10
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   129    10
#   130    10
#   131     6
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   130    10
#   131     6
#   132     5
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   131     6
#   132     5
#   133    20
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   132     5
#   133    20
#   134     6
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   133    20
#   134     6
#   135    47
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   134     6
#   135    47
#   136     9
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   135    47
#   136     9
#   137     9
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   136     9
#   137     9
#   138    12
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   137     9
#   138    12
#   139    11
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   138    12
#   139    11
#   140    17
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   139    11
#   140    17
#   141    15
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   140    17
#   141    15
#   142    14
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   141    15
#   142    14
#   143    11
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   142    14
#   143    11
#   144    97
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   143    11
#   144    97
#   145    11
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   144    97
#   145    11
#   146    12
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   145    11
#   146    12
#   147    11
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   146    12
#   147    11
#   148    14
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   147    11
#   148    14
#   149    15
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   148    14
#   149    15
#   150    12
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   149     15
#   150     12
#   151    104
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   150     12
#   151    104
#   152      5
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   151    104
#   152      5
#   153     22
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   152     5
#   153    22
#   154    45
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   153    22
#   154    45
#   155    75
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   154    45
#   155    75
#   156    29
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   155    75
#   156    29
#   157    34
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   156    29
#   157    34
#   158    20
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   157    34
#   158    20
#   159    12
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   158    20
#   159    12
#   160    25
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   159    12
#   160    25
#   161     9
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   160    25
#   161     9
#   162    62
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   161     9
#   162    62
#   163    20
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   162    62
#   163    20
#   164    19
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   163    20
#   164    19
#   165     8
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   164    19
#   165     8
#   166    23
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   165     8
#   166    23
#   167    13
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   166    23
#   167    13
#   168    16
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   167    13
#   168    16
#   169    34
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   168    16
#   169    34
#   170    36
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   169    34
#   170    36
#   171    11
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   170    36
#   171    11
#   172    18
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   171    11
#   172    18
#   173    12
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   172    18
#   173    12
#   174    24
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   173    12
#   174    24
#   175    30
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   174    24
#   175    30
#   176    27
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   175    30
#   176    27
#   177    44
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   176    27
#   177    44
#   178    35
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   177    44
#   178    35
#   179    53
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   178    35
#   179    53
#   180    11
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   179    53
#   180    11
#   181    26
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   180    11
#   181    26
#   182    13
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   181    26
#   182    13
#   183    18
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   182    13
#   183    18
#   184     9
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   183    18
#   184     9
#   185    16
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   184     9
#   185    16
#   186     6
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   185    16
#   186     6
#   187    19
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   186     6
#   187    19
#   188    20
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   187    19
#   188    20
#   189    19
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   188    20
#   189    19
#   190    22
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   189    19
#   190    22
#   191    30
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   190    22
#   191    30
#   192    14
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   191    30
#   192    14
#   193    16
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   192    14
#   193    16
#   194    22
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   193    16
#   194    22
#   195    15
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   194    22
#   195    15
#   196    15
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   195    15
#   196    15
#   197    26
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   196    15
#   197    26
#   198    16
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   197    26
#   198    16
#   199    13
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   198    16
#   199    13
#   200    27
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   199    13
#   200    27
#   201    18
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   200    27
#   201    18
#   202    13
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   201    18
#   202    13
#   203    32
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   202    13
#   203    32
#   204    31
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   203    32
#   204    31
#   205    16
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   204    31
#   205    16
#   206    38
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   205    16
#   206    38
#   207    18
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   206    38
#   207    18
#   208     9
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   207    18
#   208     9
#   209    14
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   208     9
#   209    14
#   210    10
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   209    14
#   210    10
#   211    24
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   210    10
#   211    24
#   212     8
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   211    24
#   212     8
#   213    15
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   212     8
#   213    15
#   214    18
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   213    15
#   214    18
#   215    10
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   214    18
#   215    10
#   216    23
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   215    10
#   216    23
#   217    17
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   216    23
#   217    17
#   218    11
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   217    17
#   218    11
#   219    26
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   218    11
#   219    26
#   220    14
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   219    26
#   220    14
#   221     8
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   220    14
#   221     8
#   222    12
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   221     8
#   222    12
#   223     9
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   222    12
#   223     9
#   224    11
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   223     9
#   224    11
#   225    34
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   224    11
#   225    34
#   226    17
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   225    34
#   226    17
#   227    29
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   226    17
#   227    29
#   228    11
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   227    29
#   228    11
#   229     9
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   228    11
#   229     9
#   230    14
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   229     9
#   230    14
#   231    21
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   230    14
#   231    21
#   232    12
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   231    21
#   232    12
#   233    11
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   232    12
#   233    11
#   234    13
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   233    11
#   234    13
#   235    11
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   234    13
#   235    11
#   236    13
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   235    11
#   236    13
#   237    16
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   236    13
#   237    16
#   238    13
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   237    16
#   238    13
#   239    19
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   238    13
#   239    19
#   240    21
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   239    19
#   240    21
#   241    14
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   240    21
#   241    14
#   242    11
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   241    14
#   242    11
#   243    35
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   242    11
#   243    35
#   244    18
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   243    35
#   244    18
#   245    42
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   244    18
#   245    42
#   246    15
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   245    42
#   246    15
#   247     5
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   246    15
#   247     5
#   248    21
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   247     5
#   248    21
#   249    56
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   248    21
#   249    56
#   250     9
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   249    56
#   250     9
#   251    20
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   250     9
#   251    20
#   252    17
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   251    20
#   252    17
#   253    18
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   252    17
#   253    18
#   254     8
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   253    18
#   254     8
#   255     9
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   254     8
#   255     9
#   256    17
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   255     9
#   256    17
#   257     9
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   256    17
#   257     9
#   258    10
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   257     9
#   258    10
#   259    14
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   258    10
#   259    14
#   260    17
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   259    14
#   260    17
#   261     6
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   260    17
#   261     6
#   262    18
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   261     6
#   262    18
#   263    13
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   262    18
#   263    13
#   264    11
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   263    13
#   264    11
#   265    12
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   264    11
#   265    12
#   266    11
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   265    12
#   266    11
#   267     8
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   266    11
#   267     8
#   268    15
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   267     8
#   268    15
#   269    11
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   268    15
#   269    11
#   270    20
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   269    11
#   270    20
#   271    59
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   270    20
#   271    59
#   272    11
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   271    59
#   272    11
#   273    18
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   272    11
#   273    18
#   274    17
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   273    18
#   274    17
#   275    12
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   274    17
#   275    12
#   276    14
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   275    12
#   276    14
#   277    13
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   276    14
#   277    13
#   278     9
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   277     13
#   278      9
#   279    490
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   278      9
#   279    490
#   280    189
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   279    490
#   280    189
#   281    102
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   280    189
#   281    102
#   282     38
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   281    102
#   282     38
#   283    126
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   282     38
#   283    126
#   284     71
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   283    126
#   284     71
#   285     21
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   284    71
#   285    21
#   286    57
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   285    21
#   286    57
#   287    79
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   286    57
#   287    79
#   288    17
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   287    79
#   288    17
#   289    17
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   288    17
#   289    17
#   290    23
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   289    17
#   290    23
#   291    16
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   290    23
#   291    16
#   292    23
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   291    16
#   292    23
#   293    18
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   292    23
#   293    18
#   294    22
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   293    18
#   294    22
#   295    44
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   294    22
#   295    44
#   296     6
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   295    44
#   296     6
#   297    31
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   296     6
#   297    31
#   298    17
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   297    31
#   298    17
#   299    25
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   298    17
#   299    25
#   300    40
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   299    25
#   300    40
#   301    19
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   300    40
#   301    19
#   302    15
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   301    19
#   302    15
#   303    15
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   302    15
#   303    15
#   304    29
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   303    15
#   304    29
#   305    18
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   304    29
#   305    18
#   306    16
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   305    18
#   306    16
#   307    13
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   306    16
#   307    13
#   308    20
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   307    13
#   308    20
#   309    22
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   308    20
#   309    22
#   310    19
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   309    22
#   310    19
#   311    11
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   310    19
#   311    11
#   312    50
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   311    11
#   312    50
#   313    22
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   312    50
#   313    22
#   314    39
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   313    22
#   314    39
#   315    23
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   314    39
#   315    23
#   316    21
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   315    23
#   316    21
#   317    23
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   316    21
#   317    23
#   318    22
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   317    23
#   318    22
#   319    16
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   318    22
#   319    16
#   320    19
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   319    16
#   320    19
#   321    35
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   320    19
#   321    35
#   322    16
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   321    35
#   322    16
#   323    12
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   322    16
#   323    12
#   324    15
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   323    12
#   324    15
#   325    13
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   324    15
#   325    13
#   326    14
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   325    13
#   326    14
#   327    10
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   326    14
#   327    10
#   328    21
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   327    10
#   328    21
#   329    20
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   328    21
#   329    20
#   330    19
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   329    20
#   330    19
#   331    14
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   330    19
#   331    14
#   332    12
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   331    14
#   332    12
#   333    15
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   332    12
#   333    15
#   334    17
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   333    15
#   334    17
#   335    16
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   334    17
#   335    16
#   336    21
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   335    16
#   336    21
#   337    27
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   336    21
#   337    27
#   338    13
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   337    27
#   338    13
#   339    11
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   338    13
#   339    11
#   340    15
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   339    11
#   340    15
#   341    14
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   340    15
#   341    14
#   342    18
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   341    14
#   342    18
#   343    18
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   342    18
#   343    18
#   344    10
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   343    18
#   344    10
#   345    11
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   344    10
#   345    11
#   346    14
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   345    11
#   346    14
#   347    18
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   346    14
#   347    18
#   348    14
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   347    18
#   348    14
#   349    13
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   348    14
#   349    13
#   350    17
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   349    13
#   350    17
#   351    15
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   350    17
#   351    15
#   352    14
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   351     15
#   352     14
#   353    234
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   352     14
#   353    234
#   354      8
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   353    234
#   354      8
#   355     62
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   354     8
#   355    62
#   356    26
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   355    62
#   356    26
#   357    22
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   356    26
#   357    22
#   358     8
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   357    22
#   358     8
#   359    22
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   358     8
#   359    22
#   360    15
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   359    22
#   360    15
#   361    69
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   360    15
#   361    69
#   362    11
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   361    69
#   362    11
#   363    18
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   362    11
#   363    18
#   364    23
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   363    18
#   364    23
#   365    12
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   364    23
#   365    12
#   366    20
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   365    12
#   366    20
#   367    17
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   366    20
#   367    17
#   368    15
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   367    17
#   368    15
#   369    16
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   368    15
#   369    16
#   370    18
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   369    16
#   370    18
#   371    21
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   370    18
#   371    21
#   372    15
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   371    21
#   372    15
#   373    30
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   372     15
#   373     30
#   374    115
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   373     30
#   374    115
#   375     56
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   374    115
#   375     56
#   376     45
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   375    56
#   376    45
#   377    17
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   376    45
#   377    17
#   378    18
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   377    17
#   378    18
#   379    15
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   378    18
#   379    15
#   380    18
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   379    15
#   380    18
#   381    14
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   380    18
#   381    14
#   382    15
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   381    14
#   382    15
#   383    15
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   382    15
#   383    15
#   384    24
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   383    15
#   384    24
#   385    22
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   384    24
#   385    22
#   386    18
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   385    22
#   386    18
#   387    30
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   386    18
#   387    30
#   388    12
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   387    30
#   388    12
#   389    13
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   388    12
#   389    13
#   390    18
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   389    13
#   390    18
#   391    17
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   390    18
#   391    17
#   392    31
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   391    17
#   392    31
#   393    26
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   392    31
#   393    26
#   394    29
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   393    26
#   394    29
#   395    12
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   394    29
#   395    12
#   396    19
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   395    12
#   396    19
#   397    19
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   396    19
#   397    19
#   398    57
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   397    19
#   398    57
#   399    17
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   398    57
#   399    17
#   400    20
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   399    17
#   400    20
#   401    49
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   400    20
#   401    49
#   402    10
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   401    49
#   402    10
#   403    19
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   402    10
#   403    19
#   404    26
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   403    19
#   404    26
#   405    41
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   404    26
#   405    41
#   406    23
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   405    41
#   406    23
#   407    30
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   406    23
#   407    30
#   408    55
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   407    30
#   408    55
#   409    17
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   408    55
#   409    17
#   410    24
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   409    17
#   410    24
#   411    14
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   410    24
#   411    14
#   412    12
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   411    14
#   412    12
#   413    49
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   412    12
#   413    49
#   414    42
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   413    49
#   414    42
#   415    37
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   414    42
#   415    37
#   416    13
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   415    37
#   416    13
#   417    30
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   416    13
#   417    30
#   418    20
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   417    30
#   418    20
#   419    33
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   418    20
#   419    33
#   420    20
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   419    33
#   420    20
#   421    14
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   420    20
#   421    14
#   422    40
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   421    14
#   422    40
#   423    15
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   422    40
#   423    15
#   424    18
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   423    15
#   424    18
#   425    26
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   424    18
#   425    26
#   426     8
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   425    26
#   426     8
#   427    25
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   426     8
#   427    25
#   428    21
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   427    25
#   428    21
#   429    20
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   428    21
#   429    20
#   430    25
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   429    20
#   430    25
#   431    19
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   430    25
#   431    19
#   432    23
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   431    19
#   432    23
#   433    18
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   432    23
#   433    18
#   434    19
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   433    18
#   434    19
#   435    18
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   434    19
#   435    18
#   436    55
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   435    18
#   436    55
#   437    16
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   436    55
#   437    16
#   438    65
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   437    16
#   438    65
#   439    11
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   438    65
#   439    11
#   440    11
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   439    11
#   440    11
#   441    13
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   440    11
#   441    13
#   442    20
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   441    13
#   442    20
#   443    21
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   442    20
#   443    21
#   444    13
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   443    21
#   444    13
#   445    24
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   444    13
#   445    24
#   446    20
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   445    24
#   446    20
#   447    13
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   446    20
#   447    13
#   448    32
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   447    13
#   448    32
#   449    16
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   448    32
#   449    16
#   450    10
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   449    16
#   450    10
#   451    13
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   450    10
#   451    13
#   452    44
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   451    13
#   452    44
#   453    17
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   452    44
#   453    17
#   454    13
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   453    17
#   454    13
#   455    72
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   454    13
#   455    72
#   456    40
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   455    72
#   456    40
#   457    19
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   456    40
#   457    19
#   458    14
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   457    19
#   458    14
#   459    13
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   458    14
#   459    13
#   460    12
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   459    13
#   460    12
#   461    14
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   460    12
#   461    14
#   462    10
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   461    14
#   462    10
#   463    26
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   462    10
#   463    26
#   464    13
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   463    26
#   464    13
#   465    22
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   464    13
#   465    22
#   466    14
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   465    22
#   466    14
#   467    23
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   466    14
#   467    23
#   468    12
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   467    23
#   468    12
#   469     8
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   468    12
#   469     8
#   470    50
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   469     8
#   470    50
#   471    13
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   470    50
#   471    13
#   472    10
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   471    13
#   472    10
#   473    16
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   472    10
#   473    16
#   474    14
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   473    16
#   474    14
#   475    10
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   474    14
#   475    10
#   476    24
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   475    10
#   476    24
#   477    10
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   476    24
#   477    10
#   478    20
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   477    10
#   478    20
#   479    10
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   478    20
#   479    10
#   480    26
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   479    10
#   480    26
#   481    25
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   480    26
#   481    25
#   482    16
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   481    25
#   482    16
#   483    19
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   482    16
#   483    19
#   484    20
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   483    19
#   484    20
#   485    12
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   484    20
#   485    12
#   486    19
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   485    12
#   486    19
#   487    50
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   486    19
#   487    50
#   488    16
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   487    50
#   488    16
#   489    30
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   488    16
#   489    30
#   490    18
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   489    30
#   490    18
#   491    25
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   490    18
#   491    25
#   492    14
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   491    25
#   492    14
#   493    20
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   492    14
#   493    20
#   494     8
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   493    20
#   494     8
#   495    67
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   494     8
#   495    67
#   496    13
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   495    67
#   496    13
#   497    41
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   496    13
#   497    41
#   498    10
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   497    41
#   498    10
#   499    21
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   498    10
#   499    21
#   500    13
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   499    21
#   500    13
#   501     8
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   500    13
#   501     8
#   502    15
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   501     8
#   502    15
#   503    14
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   502    15
#   503    14
#   504    12
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   503    14
#   504    12
#   505     6
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   504    12
#   505     6
#   506    11
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   505     6
#   506    11
#   507    10
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   506    11
#   507    10
#   508    42
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   507    10
#   508    42
#   509    21
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   508    42
#   509    21
#   510    24
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   509    21
#   510    24
#   511    14
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   510    24
#   511    14
#   512    11
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   511     14
#   512     11
#   513    204
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   512     11
#   513    204
#   514     14
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   513    204
#   514     14
#   515     45
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   514    14
#   515    45
#   516    33
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   515    45
#   516    33
#   517    28
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   516    33
#   517    28
#   518    18
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   517    28
#   518    18
#   519    14
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   518    18
#   519    14
#   520    47
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   519    14
#   520    47
#   521    15
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   520    47
#   521    15
#   522    14
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   521    15
#   522    14
#   523    18
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   522    14
#   523    18
#   524    20
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   523    18
#   524    20
#   525    14
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   524    20
#   525    14
#   526    16
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   525    14
#   526    16
#   527    14
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   526    16
#   527    14
#   528    20
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   527    14
#   528    20
#   529    60
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   528    20
#   529    60
#   530    22
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   529    60
#   530    22
#   531    15
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   530    22
#   531    15
#   532    17
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   531    15
#   532    17
#   533    19
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   532    17
#   533    19
#   534    18
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   533    19
#   534    18
#   535    21
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   534    18
#   535    21
#   536    21
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   535    21
#   536    21
#   537    47
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   536    21
#   537    47
#   538    65
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   537    47
#   538    65
#   539    17
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   538    65
#   539    17
#   540    32
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   539    17
#   540    32
#   541    63
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   540    32
#   541    63
#   542    15
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   541    63
#   542    15
#   543    26
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   542    15
#   543    26
#   544    14
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   543    26
#   544    14
#   545    20
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   544    14
#   545    20
#   546    22
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64,
#   545    20
#   546    22
#   547    19
#   Name: 2NE1_zh.wikipedia.org_all-access_spider, dtype: int64],
#  'target': [13,
#   14,
#   9,
#   9,
#   22,
#   26,
#   24,
#   19,
#   10,
#   14,
#   15,
#   8,
#   16,
#   8,
#   8,
#   16,
#   7,
#   11,
#   10,
#   20,
#   18,
#   15,
#   14,
#   49,
#   10,
#   16,
#   18,
#   8,
#   5,
#   9,
#   7,
#   13,
#   9,
#   7,
#   4,
#   11,
#   10,
#   5,
#   9,
#   9,
#   9,
#   9,
#   13,
#   4,
#   15,
#   25,
#   9,
#   5,
#   6,
#   20,
#   3,
#   14,
#   46,
#   5,
#   5,
#   13,
#   4,
#   9,
#   10,
#   9,
#   11,
#   11,
#   11,
#   9,
#   15,
#   5,
#   10,
#   7,
#   4,
#   8,
#   9,
#   10,
#   6,
#   13,
#   16,
#   6,
#   24,
#   9,
#   11,
#   12,
#   8,
#   14,
#   6,
#   6,
#   11,
#   14,
#   6,
#   10,
#   20,
#   7,
#   15,
#   8,
#   15,
#   5,
#   8,
#   8,
#   5,
#   11,
#   165,
#   34,
#   6,
#   13,
#   8,
#   9,
#   11,
#   26,
#   18,
#   3,
#   5,
#   12,
#   6,
#   16,
#   19,
#   9,
#   10,
#   11,
#   11,
#   7,
#   9,
#   10,
#   24,
#   6,
#   6,
#   8,
#   16,
#   13,
#   10,
#   10,
#   6,
#   5,
#   20,
#   6,
#   47,
#   9,
#   9,
#   12,
#   11,
#   17,
#   15,
#   14,
#   11,
#   97,
#   11,
#   12,
#   11,
#   14,
#   15,
#   12,
#   104,
#   5,
#   22,
#   45,
#   75,
#   29,
#   34,
#   20,
#   12,
#   25,
#   9,
#   62,
#   20,
#   19,
#   8,
#   23,
#   13,
#   16,
#   34,
#   36,
#   11,
#   18,
#   12,
#   24,
#   30,
#   27,
#   44,
#   35,
#   53,
#   11,
#   26,
#   13,
#   18,
#   9,
#   16,
#   6,
#   19,
#   20,
#   19,
#   22,
#   30,
#   14,
#   16,
#   22,
#   15,
#   15,
#   26,
#   16,
#   13,
#   27,
#   18,
#   13,
#   32,
#   31,
#   16,
#   38,
#   18,
#   9,
#   14,
#   10,
#   24,
#   8,
#   15,
#   18,
#   10,
#   23,
#   17,
#   11,
#   26,
#   14,
#   8,
#   12,
#   9,
#   11,
#   34,
#   17,
#   29,
#   11,
#   9,
#   14,
#   21,
#   12,
#   11,
#   13,
#   11,
#   13,
#   16,
#   13,
#   19,
#   21,
#   14,
#   11,
#   35,
#   18,
#   42,
#   15,
#   5,
#   21,
#   56,
#   9,
#   20,
#   17,
#   18,
#   8,
#   9,
#   17,
#   9,
#   10,
#   14,
#   17,
#   6,
#   18,
#   13,
#   11,
#   12,
#   11,
#   8,
#   15,
#   11,
#   20,
#   59,
#   11,
#   18,
#   17,
#   12,
#   14,
#   13,
#   9,
#   490,
#   189,
#   102,
#   38,
#   126,
#   71,
#   21,
#   57,
#   79,
#   17,
#   17,
#   23,
#   16,
#   23,
#   18,
#   22,
#   44,
#   6,
#   31,
#   17,
#   25,
#   40,
#   19,
#   15,
#   15,
#   29,
#   18,
#   16,
#   13,
#   20,
#   22,
#   19,
#   11,
#   50,
#   22,
#   39,
#   23,
#   21,
#   23,
#   22,
#   16,
#   19,
#   35,
#   16,
#   12,
#   15,
#   13,
#   14,
#   10,
#   21,
#   20,
#   19,
#   14,
#   12,
#   15,
#   17,
#   16,
#   21,
#   27,
#   13,
#   11,
#   15,
#   14,
#   18,
#   18,
#   10,
#   11,
#   14,
#   18,
#   14,
#   13,
#   17,
#   15,
#   14,
#   234,
#   8,
#   62,
#   26,
#   22,
#   8,
#   22,
#   15,
#   69,
#   11,
#   18,
#   23,
#   12,
#   20,
#   17,
#   15,
#   16,
#   18,
#   21,
#   15,
#   30,
#   115,
#   56,
#   45,
#   17,
#   18,
#   15,
#   18,
#   14,
#   15,
#   15,
#   24,
#   22,
#   18,
#   30,
#   12,
#   13,
#   18,
#   17,
#   31,
#   26,
#   29,
#   12,
#   19,
#   19,
#   57,
#   17,
#   20,
#   49,
#   10,
#   19,
#   26,
#   41,
#   23,
#   30,
#   55,
#   17,
#   24,
#   14,
#   12,
#   49,
#   42,
#   37,
#   13,
#   30,
#   20,
#   33,
#   20,
#   14,
#   40,
#   15,
#   18,
#   26,
#   8,
#   25,
#   21,
#   20,
#   25,
#   19,
#   23,
#   18,
#   19,
#   18,
#   55,
#   16,
#   65,
#   11,
#   11,
#   13,
#   20,
#   21,
#   13,
#   24,
#   20,
#   13,
#   32,
#   16,
#   10,
#   13,
#   44,
#   17,
#   13,
#   72,
#   40,
#   19,
#   14,
#   13,
#   12,
#   14,
#   10,
#   26,
#   13,
#   22,
#   14,
#   23,
#   12,
#   8,
#   50,
#   13,
#   10,
#   16,
#   14,
#   10,
#   24,
#   10,
#   20,
#   10,
#   26,
#   25,
#   16,
#   19,
#   20,
#   12,
#   19,
#   50,
#   16,
#   30,
#   18,
#   25,
#   14,
#   20,
#   8,
#   67,
#   13,
#   41,
#   10,
#   21,
#   13,
#   8,
#   15,
#   14,
#   12,
#   6,
#   11,
#   10,
#   42,
#   21,
#   24,
#   14,
#   11,
#   204,
#   14,
#   45,
#   33,
#   28,
#   18,
#   14,
#   47,
#   15,
#   14,
#   18,
#   20,
#   14,
#   16,
#   14,
#   20,
#   60,
#   22,
#   15,
#   17,
#   19,
#   18,
#   21,
#   21,
#   47,
#   65,
#   17,
#   32,
#   63,
#   15,
#   26,
#   14,
#   20,
#   22,
#   19,
#   18]}

# %%
pd.DataFrame(dict1)
# Out:
#                                               features  target
# 0    0    18
# 1    11
# 2     5
# Name: 2NE1_zh.wikipedi...      13
# 1    1    11
# 2     5
# 3    13
# Name: 2NE1_zh.wikipedi...      14
# 2    2     5
# 3    13
# 4    14
# Name: 2NE1_zh.wikipedi...       9
# 3    3    13
# 4    14
# 5     9
# Name: 2NE1_zh.wikipedi...       9
# 4    4    14
# 5     9
# 6     9
# Name: 2NE1_zh.wikipedi...      22
# ..                                                 ...     ...
# 541  541    63
# 542    15
# 543    26
# Name: 2NE1_zh.wi...      14
# 542  542    15
# 543    26
# 544    14
# Name: 2NE1_zh.wi...      20
# 543  543    26
# 544    14
# 545    20
# Name: 2NE1_zh.wi...      22
# 544  544    14
# 545    20
# 546    22
# Name: 2NE1_zh.wi...      19
# 545  545    20
# 546    22
# 547    19
# Name: 2NE1_zh.wi...      18
#
# [546 rows x 2 columns]

# %%
def create_dataset(dataset, col_name = '2NE1_zh.wikipedia.org_all-access_spider', window_size = 3):
    data_X, data_Y = [], []
    for i in range(len(dataset) - window_size): 
        a = dataset[i:(i + window_size)][col_name]
        data_X.append(a)
        data_Y.append(dataset.loc[i + window_size][col_name])
    return(np.array(data_X), np.array(data_Y))

# %%
features, target_val = create_dataset(df)

# %%
features
# Out:
# array([[18, 11,  5],
#        [11,  5, 13],
#        [ 5, 13, 14],
#        ...,
#        [14, 20, 22],
#        [20, 22, 19],
#        [22, 19, 18]], dtype=int64)

# %%
tuple_list = list(zip(features, target_val))

# %%
len(tuple_list)
# Out:
# 547

# %%
tuple_list[0]
# Out:
# (array([18, 11,  5], dtype=int64), 13)

# %%
tuple_list[0][0][0]
# Out:
# 18

# %%
tuple_list[:]
# Out:
# [(array([18, 11,  5], dtype=int64), 13),
#  (array([11,  5, 13], dtype=int64), 14),
#  (array([ 5, 13, 14], dtype=int64), 9),
#  (array([13, 14,  9], dtype=int64), 9),
#  (array([14,  9,  9], dtype=int64), 22),
#  (array([ 9,  9, 22], dtype=int64), 26),
#  (array([ 9, 22, 26], dtype=int64), 24),
#  (array([22, 26, 24], dtype=int64), 19),
#  (array([26, 24, 19], dtype=int64), 10),
#  (array([24, 19, 10], dtype=int64), 14),
#  (array([19, 10, 14], dtype=int64), 15),
#  (array([10, 14, 15], dtype=int64), 8),
#  (array([14, 15,  8], dtype=int64), 16),
#  (array([15,  8, 16], dtype=int64), 8),
#  (array([ 8, 16,  8], dtype=int64), 8),
#  (array([16,  8,  8], dtype=int64), 16),
#  (array([ 8,  8, 16], dtype=int64), 7),
#  (array([ 8, 16,  7], dtype=int64), 11),
#  (array([16,  7, 11], dtype=int64), 10),
#  (array([ 7, 11, 10], dtype=int64), 20),
#  (array([11, 10, 20], dtype=int64), 18),
#  (array([10, 20, 18], dtype=int64), 15),
#  (array([20, 18, 15], dtype=int64), 14),
#  (array([18, 15, 14], dtype=int64), 49),
#  (array([15, 14, 49], dtype=int64), 10),
#  (array([14, 49, 10], dtype=int64), 16),
#  (array([49, 10, 16], dtype=int64), 18),
#  (array([10, 16, 18], dtype=int64), 8),
#  (array([16, 18,  8], dtype=int64), 5),
#  (array([18,  8,  5], dtype=int64), 9),
#  (array([8, 5, 9], dtype=int64), 7),
#  (array([5, 9, 7], dtype=int64), 13),
#  (array([ 9,  7, 13], dtype=int64), 9),
#  (array([ 7, 13,  9], dtype=int64), 7),
#  (array([13,  9,  7], dtype=int64), 4),
#  (array([9, 7, 4], dtype=int64), 11),
#  (array([ 7,  4, 11], dtype=int64), 10),
#  (array([ 4, 11, 10], dtype=int64), 5),
#  (array([11, 10,  5], dtype=int64), 9),
#  (array([10,  5,  9], dtype=int64), 9),
#  (array([5, 9, 9], dtype=int64), 9),
#  (array([9, 9, 9], dtype=int64), 9),
#  (array([9, 9, 9], dtype=int64), 13),
#  (array([ 9,  9, 13], dtype=int64), 4),
#  (array([ 9, 13,  4], dtype=int64), 15),
#  (array([13,  4, 15], dtype=int64), 25),
#  (array([ 4, 15, 25], dtype=int64), 9),
#  (array([15, 25,  9], dtype=int64), 5),
#  (array([25,  9,  5], dtype=int64), 6),
#  (array([9, 5, 6], dtype=int64), 20),
#  (array([ 5,  6, 20], dtype=int64), 3),
#  (array([ 6, 20,  3], dtype=int64), 14),
#  (array([20,  3, 14], dtype=int64), 46),
#  (array([ 3, 14, 46], dtype=int64), 5),
#  (array([14, 46,  5], dtype=int64), 5),
#  (array([46,  5,  5], dtype=int64), 13),
#  (array([ 5,  5, 13], dtype=int64), 4),
#  (array([ 5, 13,  4], dtype=int64), 9),
#  (array([13,  4,  9], dtype=int64), 10),
#  (array([ 4,  9, 10], dtype=int64), 9),
#  (array([ 9, 10,  9], dtype=int64), 11),
#  (array([10,  9, 11], dtype=int64), 11),
#  (array([ 9, 11, 11], dtype=int64), 11),
#  (array([11, 11, 11], dtype=int64), 9),
#  (array([11, 11,  9], dtype=int64), 15),
#  (array([11,  9, 15], dtype=int64), 5),
#  (array([ 9, 15,  5], dtype=int64), 10),
#  (array([15,  5, 10], dtype=int64), 7),
#  (array([ 5, 10,  7], dtype=int64), 4),
#  (array([10,  7,  4], dtype=int64), 8),
#  (array([7, 4, 8], dtype=int64), 9),
#  (array([4, 8, 9], dtype=int64), 10),
#  (array([ 8,  9, 10], dtype=int64), 6),
#  (array([ 9, 10,  6], dtype=int64), 13),
#  (array([10,  6, 13], dtype=int64), 16),
#  (array([ 6, 13, 16], dtype=int64), 6),
#  (array([13, 16,  6], dtype=int64), 24),
#  (array([16,  6, 24], dtype=int64), 9),
#  (array([ 6, 24,  9], dtype=int64), 11),
#  (array([24,  9, 11], dtype=int64), 12),
#  (array([ 9, 11, 12], dtype=int64), 8),
#  (array([11, 12,  8], dtype=int64), 14),
#  (array([12,  8, 14], dtype=int64), 6),
#  (array([ 8, 14,  6], dtype=int64), 6),
#  (array([14,  6,  6], dtype=int64), 11),
#  (array([ 6,  6, 11], dtype=int64), 14),
#  (array([ 6, 11, 14], dtype=int64), 6),
#  (array([11, 14,  6], dtype=int64), 10),
#  (array([14,  6, 10], dtype=int64), 20),
#  (array([ 6, 10, 20], dtype=int64), 7),
#  (array([10, 20,  7], dtype=int64), 15),
#  (array([20,  7, 15], dtype=int64), 8),
#  (array([ 7, 15,  8], dtype=int64), 15),
#  (array([15,  8, 15], dtype=int64), 5),
#  (array([ 8, 15,  5], dtype=int64), 8),
#  (array([15,  5,  8], dtype=int64), 8),
#  (array([5, 8, 8], dtype=int64), 5),
#  (array([8, 8, 5], dtype=int64), 11),
#  (array([ 8,  5, 11], dtype=int64), 165),
#  (array([  5,  11, 165], dtype=int64), 34),
#  (array([ 11, 165,  34], dtype=int64), 6),
#  (array([165,  34,   6], dtype=int64), 13),
#  (array([34,  6, 13], dtype=int64), 8),
#  (array([ 6, 13,  8], dtype=int64), 9),
#  (array([13,  8,  9], dtype=int64), 11),
#  (array([ 8,  9, 11], dtype=int64), 26),
#  (array([ 9, 11, 26], dtype=int64), 18),
#  (array([11, 26, 18], dtype=int64), 3),
#  (array([26, 18,  3], dtype=int64), 5),
#  (array([18,  3,  5], dtype=int64), 12),
#  (array([ 3,  5, 12], dtype=int64), 6),
#  (array([ 5, 12,  6], dtype=int64), 16),
#  (array([12,  6, 16], dtype=int64), 19),
#  (array([ 6, 16, 19], dtype=int64), 9),
#  (array([16, 19,  9], dtype=int64), 10),
#  (array([19,  9, 10], dtype=int64), 11),
#  (array([ 9, 10, 11], dtype=int64), 11),
#  (array([10, 11, 11], dtype=int64), 7),
#  (array([11, 11,  7], dtype=int64), 9),
#  (array([11,  7,  9], dtype=int64), 10),
#  (array([ 7,  9, 10], dtype=int64), 24),
#  (array([ 9, 10, 24], dtype=int64), 6),
#  (array([10, 24,  6], dtype=int64), 6),
#  (array([24,  6,  6], dtype=int64), 8),
#  (array([6, 6, 8], dtype=int64), 16),
#  (array([ 6,  8, 16], dtype=int64), 13),
#  (array([ 8, 16, 13], dtype=int64), 10),
#  (array([16, 13, 10], dtype=int64), 10),
#  (array([13, 10, 10], dtype=int64), 6),
#  (array([10, 10,  6], dtype=int64), 5),
#  (array([10,  6,  5], dtype=int64), 20),
#  (array([ 6,  5, 20], dtype=int64), 6),
#  (array([ 5, 20,  6], dtype=int64), 47),
#  (array([20,  6, 47], dtype=int64), 9),
#  (array([ 6, 47,  9], dtype=int64), 9),
#  (array([47,  9,  9], dtype=int64), 12),
#  (array([ 9,  9, 12], dtype=int64), 11),
#  (array([ 9, 12, 11], dtype=int64), 17),
#  (array([12, 11, 17], dtype=int64), 15),
#  (array([11, 17, 15], dtype=int64), 14),
#  (array([17, 15, 14], dtype=int64), 11),
#  (array([15, 14, 11], dtype=int64), 97),
#  (array([14, 11, 97], dtype=int64), 11),
#  (array([11, 97, 11], dtype=int64), 12),
#  (array([97, 11, 12], dtype=int64), 11),
#  (array([11, 12, 11], dtype=int64), 14),
#  (array([12, 11, 14], dtype=int64), 15),
#  (array([11, 14, 15], dtype=int64), 12),
#  (array([14, 15, 12], dtype=int64), 104),
#  (array([ 15,  12, 104], dtype=int64), 5),
#  (array([ 12, 104,   5], dtype=int64), 22),
#  (array([104,   5,  22], dtype=int64), 45),
#  (array([ 5, 22, 45], dtype=int64), 75),
#  (array([22, 45, 75], dtype=int64), 29),
#  (array([45, 75, 29], dtype=int64), 34),
#  (array([75, 29, 34], dtype=int64), 20),
#  (array([29, 34, 20], dtype=int64), 12),
#  (array([34, 20, 12], dtype=int64), 25),
#  (array([20, 12, 25], dtype=int64), 9),
#  (array([12, 25,  9], dtype=int64), 62),
#  (array([25,  9, 62], dtype=int64), 20),
#  (array([ 9, 62, 20], dtype=int64), 19),
#  (array([62, 20, 19], dtype=int64), 8),
#  (array([20, 19,  8], dtype=int64), 23),
#  (array([19,  8, 23], dtype=int64), 13),
#  (array([ 8, 23, 13], dtype=int64), 16),
#  (array([23, 13, 16], dtype=int64), 34),
#  (array([13, 16, 34], dtype=int64), 36),
#  (array([16, 34, 36], dtype=int64), 11),
#  (array([34, 36, 11], dtype=int64), 18),
#  (array([36, 11, 18], dtype=int64), 12),
#  (array([11, 18, 12], dtype=int64), 24),
#  (array([18, 12, 24], dtype=int64), 30),
#  (array([12, 24, 30], dtype=int64), 27),
#  (array([24, 30, 27], dtype=int64), 44),
#  (array([30, 27, 44], dtype=int64), 35),
#  (array([27, 44, 35], dtype=int64), 53),
#  (array([44, 35, 53], dtype=int64), 11),
#  (array([35, 53, 11], dtype=int64), 26),
#  (array([53, 11, 26], dtype=int64), 13),
#  (array([11, 26, 13], dtype=int64), 18),
#  (array([26, 13, 18], dtype=int64), 9),
#  (array([13, 18,  9], dtype=int64), 16),
#  (array([18,  9, 16], dtype=int64), 6),
#  (array([ 9, 16,  6], dtype=int64), 19),
#  (array([16,  6, 19], dtype=int64), 20),
#  (array([ 6, 19, 20], dtype=int64), 19),
#  (array([19, 20, 19], dtype=int64), 22),
#  (array([20, 19, 22], dtype=int64), 30),
#  (array([19, 22, 30], dtype=int64), 14),
#  (array([22, 30, 14], dtype=int64), 16),
#  (array([30, 14, 16], dtype=int64), 22),
#  (array([14, 16, 22], dtype=int64), 15),
#  (array([16, 22, 15], dtype=int64), 15),
#  (array([22, 15, 15], dtype=int64), 26),
#  (array([15, 15, 26], dtype=int64), 16),
#  (array([15, 26, 16], dtype=int64), 13),
#  (array([26, 16, 13], dtype=int64), 27),
#  (array([16, 13, 27], dtype=int64), 18),
#  (array([13, 27, 18], dtype=int64), 13),
#  (array([27, 18, 13], dtype=int64), 32),
#  (array([18, 13, 32], dtype=int64), 31),
#  (array([13, 32, 31], dtype=int64), 16),
#  (array([32, 31, 16], dtype=int64), 38),
#  (array([31, 16, 38], dtype=int64), 18),
#  (array([16, 38, 18], dtype=int64), 9),
#  (array([38, 18,  9], dtype=int64), 14),
#  (array([18,  9, 14], dtype=int64), 10),
#  (array([ 9, 14, 10], dtype=int64), 24),
#  (array([14, 10, 24], dtype=int64), 8),
#  (array([10, 24,  8], dtype=int64), 15),
#  (array([24,  8, 15], dtype=int64), 18),
#  (array([ 8, 15, 18], dtype=int64), 10),
#  (array([15, 18, 10], dtype=int64), 23),
#  (array([18, 10, 23], dtype=int64), 17),
#  (array([10, 23, 17], dtype=int64), 11),
#  (array([23, 17, 11], dtype=int64), 26),
#  (array([17, 11, 26], dtype=int64), 14),
#  (array([11, 26, 14], dtype=int64), 8),
#  (array([26, 14,  8], dtype=int64), 12),
#  (array([14,  8, 12], dtype=int64), 9),
#  (array([ 8, 12,  9], dtype=int64), 11),
#  (array([12,  9, 11], dtype=int64), 34),
#  (array([ 9, 11, 34], dtype=int64), 17),
#  (array([11, 34, 17], dtype=int64), 29),
#  (array([34, 17, 29], dtype=int64), 11),
#  (array([17, 29, 11], dtype=int64), 9),
#  (array([29, 11,  9], dtype=int64), 14),
#  (array([11,  9, 14], dtype=int64), 21),
#  (array([ 9, 14, 21], dtype=int64), 12),
#  (array([14, 21, 12], dtype=int64), 11),
#  (array([21, 12, 11], dtype=int64), 13),
#  (array([12, 11, 13], dtype=int64), 11),
#  (array([11, 13, 11], dtype=int64), 13),
#  (array([13, 11, 13], dtype=int64), 16),
#  (array([11, 13, 16], dtype=int64), 13),
#  (array([13, 16, 13], dtype=int64), 19),
#  (array([16, 13, 19], dtype=int64), 21),
#  (array([13, 19, 21], dtype=int64), 14),
#  (array([19, 21, 14], dtype=int64), 11),
#  (array([21, 14, 11], dtype=int64), 35),
#  (array([14, 11, 35], dtype=int64), 18),
#  (array([11, 35, 18], dtype=int64), 42),
#  (array([35, 18, 42], dtype=int64), 15),
#  (array([18, 42, 15], dtype=int64), 5),
#  (array([42, 15,  5], dtype=int64), 21),
#  (array([15,  5, 21], dtype=int64), 56),
#  (array([ 5, 21, 56], dtype=int64), 9),
#  (array([21, 56,  9], dtype=int64), 20),
#  (array([56,  9, 20], dtype=int64), 17),
#  (array([ 9, 20, 17], dtype=int64), 18),
#  (array([20, 17, 18], dtype=int64), 8),
#  (array([17, 18,  8], dtype=int64), 9),
#  (array([18,  8,  9], dtype=int64), 17),
#  (array([ 8,  9, 17], dtype=int64), 9),
#  (array([ 9, 17,  9], dtype=int64), 10),
#  (array([17,  9, 10], dtype=int64), 14),
#  (array([ 9, 10, 14], dtype=int64), 17),
#  (array([10, 14, 17], dtype=int64), 6),
#  (array([14, 17,  6], dtype=int64), 18),
#  (array([17,  6, 18], dtype=int64), 13),
#  (array([ 6, 18, 13], dtype=int64), 11),
#  (array([18, 13, 11], dtype=int64), 12),
#  (array([13, 11, 12], dtype=int64), 11),
#  (array([11, 12, 11], dtype=int64), 8),
#  (array([12, 11,  8], dtype=int64), 15),
#  (array([11,  8, 15], dtype=int64), 11),
#  (array([ 8, 15, 11], dtype=int64), 20),
#  (array([15, 11, 20], dtype=int64), 59),
#  (array([11, 20, 59], dtype=int64), 11),
#  (array([20, 59, 11], dtype=int64), 18),
#  (array([59, 11, 18], dtype=int64), 17),
#  (array([11, 18, 17], dtype=int64), 12),
#  (array([18, 17, 12], dtype=int64), 14),
#  (array([17, 12, 14], dtype=int64), 13),
#  (array([12, 14, 13], dtype=int64), 9),
#  (array([14, 13,  9], dtype=int64), 490),
#  (array([ 13,   9, 490], dtype=int64), 189),
#  (array([  9, 490, 189], dtype=int64), 102),
#  (array([490, 189, 102], dtype=int64), 38),
#  (array([189, 102,  38], dtype=int64), 126),
#  (array([102,  38, 126], dtype=int64), 71),
#  (array([ 38, 126,  71], dtype=int64), 21),
#  (array([126,  71,  21], dtype=int64), 57),
#  (array([71, 21, 57], dtype=int64), 79),
#  (array([21, 57, 79], dtype=int64), 17),
#  (array([57, 79, 17], dtype=int64), 17),
#  (array([79, 17, 17], dtype=int64), 23),
#  (array([17, 17, 23], dtype=int64), 16),
#  (array([17, 23, 16], dtype=int64), 23),
#  (array([23, 16, 23], dtype=int64), 18),
#  (array([16, 23, 18], dtype=int64), 22),
#  (array([23, 18, 22], dtype=int64), 44),
#  (array([18, 22, 44], dtype=int64), 6),
#  (array([22, 44,  6], dtype=int64), 31),
#  (array([44,  6, 31], dtype=int64), 17),
#  (array([ 6, 31, 17], dtype=int64), 25),
#  (array([31, 17, 25], dtype=int64), 40),
#  (array([17, 25, 40], dtype=int64), 19),
#  (array([25, 40, 19], dtype=int64), 15),
#  (array([40, 19, 15], dtype=int64), 15),
#  (array([19, 15, 15], dtype=int64), 29),
#  (array([15, 15, 29], dtype=int64), 18),
#  (array([15, 29, 18], dtype=int64), 16),
#  (array([29, 18, 16], dtype=int64), 13),
#  (array([18, 16, 13], dtype=int64), 20),
#  (array([16, 13, 20], dtype=int64), 22),
#  (array([13, 20, 22], dtype=int64), 19),
#  (array([20, 22, 19], dtype=int64), 11),
#  (array([22, 19, 11], dtype=int64), 50),
#  (array([19, 11, 50], dtype=int64), 22),
#  (array([11, 50, 22], dtype=int64), 39),
#  (array([50, 22, 39], dtype=int64), 23),
#  (array([22, 39, 23], dtype=int64), 21),
#  (array([39, 23, 21], dtype=int64), 23),
#  (array([23, 21, 23], dtype=int64), 22),
#  (array([21, 23, 22], dtype=int64), 16),
#  (array([23, 22, 16], dtype=int64), 19),
#  (array([22, 16, 19], dtype=int64), 35),
#  (array([16, 19, 35], dtype=int64), 16),
#  (array([19, 35, 16], dtype=int64), 12),
#  (array([35, 16, 12], dtype=int64), 15),
#  (array([16, 12, 15], dtype=int64), 13),
#  (array([12, 15, 13], dtype=int64), 14),
#  (array([15, 13, 14], dtype=int64), 10),
#  (array([13, 14, 10], dtype=int64), 21),
#  (array([14, 10, 21], dtype=int64), 20),
#  (array([10, 21, 20], dtype=int64), 19),
#  (array([21, 20, 19], dtype=int64), 14),
#  (array([20, 19, 14], dtype=int64), 12),
#  (array([19, 14, 12], dtype=int64), 15),
#  (array([14, 12, 15], dtype=int64), 17),
#  (array([12, 15, 17], dtype=int64), 16),
#  (array([15, 17, 16], dtype=int64), 21),
#  (array([17, 16, 21], dtype=int64), 27),
#  (array([16, 21, 27], dtype=int64), 13),
#  (array([21, 27, 13], dtype=int64), 11),
#  (array([27, 13, 11], dtype=int64), 15),
#  (array([13, 11, 15], dtype=int64), 14),
#  (array([11, 15, 14], dtype=int64), 18),
#  (array([15, 14, 18], dtype=int64), 18),
#  (array([14, 18, 18], dtype=int64), 10),
#  (array([18, 18, 10], dtype=int64), 11),
#  (array([18, 10, 11], dtype=int64), 14),
#  (array([10, 11, 14], dtype=int64), 18),
#  (array([11, 14, 18], dtype=int64), 14),
#  (array([14, 18, 14], dtype=int64), 13),
#  (array([18, 14, 13], dtype=int64), 17),
#  (array([14, 13, 17], dtype=int64), 15),
#  (array([13, 17, 15], dtype=int64), 14),
#  (array([17, 15, 14], dtype=int64), 234),
#  (array([ 15,  14, 234], dtype=int64), 8),
#  (array([ 14, 234,   8], dtype=int64), 62),
#  (array([234,   8,  62], dtype=int64), 26),
#  (array([ 8, 62, 26], dtype=int64), 22),
#  (array([62, 26, 22], dtype=int64), 8),
#  (array([26, 22,  8], dtype=int64), 22),
#  (array([22,  8, 22], dtype=int64), 15),
#  (array([ 8, 22, 15], dtype=int64), 69),
#  (array([22, 15, 69], dtype=int64), 11),
#  (array([15, 69, 11], dtype=int64), 18),
#  (array([69, 11, 18], dtype=int64), 23),
#  (array([11, 18, 23], dtype=int64), 12),
#  (array([18, 23, 12], dtype=int64), 20),
#  (array([23, 12, 20], dtype=int64), 17),
#  (array([12, 20, 17], dtype=int64), 15),
#  (array([20, 17, 15], dtype=int64), 16),
#  (array([17, 15, 16], dtype=int64), 18),
#  (array([15, 16, 18], dtype=int64), 21),
#  (array([16, 18, 21], dtype=int64), 15),
#  (array([18, 21, 15], dtype=int64), 30),
#  (array([21, 15, 30], dtype=int64), 115),
#  (array([ 15,  30, 115], dtype=int64), 56),
#  (array([ 30, 115,  56], dtype=int64), 45),
#  (array([115,  56,  45], dtype=int64), 17),
#  (array([56, 45, 17], dtype=int64), 18),
#  (array([45, 17, 18], dtype=int64), 15),
#  (array([17, 18, 15], dtype=int64), 18),
#  (array([18, 15, 18], dtype=int64), 14),
#  (array([15, 18, 14], dtype=int64), 15),
#  (array([18, 14, 15], dtype=int64), 15),
#  (array([14, 15, 15], dtype=int64), 24),
#  (array([15, 15, 24], dtype=int64), 22),
#  (array([15, 24, 22], dtype=int64), 18),
#  (array([24, 22, 18], dtype=int64), 30),
#  (array([22, 18, 30], dtype=int64), 12),
#  (array([18, 30, 12], dtype=int64), 13),
#  (array([30, 12, 13], dtype=int64), 18),
#  (array([12, 13, 18], dtype=int64), 17),
#  (array([13, 18, 17], dtype=int64), 31),
#  (array([18, 17, 31], dtype=int64), 26),
#  (array([17, 31, 26], dtype=int64), 29),
#  (array([31, 26, 29], dtype=int64), 12),
#  (array([26, 29, 12], dtype=int64), 19),
#  (array([29, 12, 19], dtype=int64), 19),
#  (array([12, 19, 19], dtype=int64), 57),
#  (array([19, 19, 57], dtype=int64), 17),
#  (array([19, 57, 17], dtype=int64), 20),
#  (array([57, 17, 20], dtype=int64), 49),
#  (array([17, 20, 49], dtype=int64), 10),
#  (array([20, 49, 10], dtype=int64), 19),
#  (array([49, 10, 19], dtype=int64), 26),
#  (array([10, 19, 26], dtype=int64), 41),
#  (array([19, 26, 41], dtype=int64), 23),
#  (array([26, 41, 23], dtype=int64), 30),
#  (array([41, 23, 30], dtype=int64), 55),
#  (array([23, 30, 55], dtype=int64), 17),
#  (array([30, 55, 17], dtype=int64), 24),
#  (array([55, 17, 24], dtype=int64), 14),
#  (array([17, 24, 14], dtype=int64), 12),
#  (array([24, 14, 12], dtype=int64), 49),
#  (array([14, 12, 49], dtype=int64), 42),
#  (array([12, 49, 42], dtype=int64), 37),
#  (array([49, 42, 37], dtype=int64), 13),
#  (array([42, 37, 13], dtype=int64), 30),
#  (array([37, 13, 30], dtype=int64), 20),
#  (array([13, 30, 20], dtype=int64), 33),
#  (array([30, 20, 33], dtype=int64), 20),
#  (array([20, 33, 20], dtype=int64), 14),
#  (array([33, 20, 14], dtype=int64), 40),
#  (array([20, 14, 40], dtype=int64), 15),
#  (array([14, 40, 15], dtype=int64), 18),
#  (array([40, 15, 18], dtype=int64), 26),
#  (array([15, 18, 26], dtype=int64), 8),
#  (array([18, 26,  8], dtype=int64), 25),
#  (array([26,  8, 25], dtype=int64), 21),
#  (array([ 8, 25, 21], dtype=int64), 20),
#  (array([25, 21, 20], dtype=int64), 25),
#  (array([21, 20, 25], dtype=int64), 19),
#  (array([20, 25, 19], dtype=int64), 23),
#  (array([25, 19, 23], dtype=int64), 18),
#  (array([19, 23, 18], dtype=int64), 19),
#  (array([23, 18, 19], dtype=int64), 18),
#  (array([18, 19, 18], dtype=int64), 55),
#  (array([19, 18, 55], dtype=int64), 16),
#  (array([18, 55, 16], dtype=int64), 65),
#  (array([55, 16, 65], dtype=int64), 11),
#  (array([16, 65, 11], dtype=int64), 11),
#  (array([65, 11, 11], dtype=int64), 13),
#  (array([11, 11, 13], dtype=int64), 20),
#  (array([11, 13, 20], dtype=int64), 21),
#  (array([13, 20, 21], dtype=int64), 13),
#  (array([20, 21, 13], dtype=int64), 24),
#  (array([21, 13, 24], dtype=int64), 20),
#  (array([13, 24, 20], dtype=int64), 13),
#  (array([24, 20, 13], dtype=int64), 32),
#  (array([20, 13, 32], dtype=int64), 16),
#  (array([13, 32, 16], dtype=int64), 10),
#  (array([32, 16, 10], dtype=int64), 13),
#  (array([16, 10, 13], dtype=int64), 44),
#  (array([10, 13, 44], dtype=int64), 17),
#  (array([13, 44, 17], dtype=int64), 13),
#  (array([44, 17, 13], dtype=int64), 72),
#  (array([17, 13, 72], dtype=int64), 40),
#  (array([13, 72, 40], dtype=int64), 19),
#  (array([72, 40, 19], dtype=int64), 14),
#  (array([40, 19, 14], dtype=int64), 13),
#  (array([19, 14, 13], dtype=int64), 12),
#  (array([14, 13, 12], dtype=int64), 14),
#  (array([13, 12, 14], dtype=int64), 10),
#  (array([12, 14, 10], dtype=int64), 26),
#  (array([14, 10, 26], dtype=int64), 13),
#  (array([10, 26, 13], dtype=int64), 22),
#  (array([26, 13, 22], dtype=int64), 14),
#  (array([13, 22, 14], dtype=int64), 23),
#  (array([22, 14, 23], dtype=int64), 12),
#  (array([14, 23, 12], dtype=int64), 8),
#  (array([23, 12,  8], dtype=int64), 50),
#  (array([12,  8, 50], dtype=int64), 13),
#  (array([ 8, 50, 13], dtype=int64), 10),
#  (array([50, 13, 10], dtype=int64), 16),
#  (array([13, 10, 16], dtype=int64), 14),
#  (array([10, 16, 14], dtype=int64), 10),
#  (array([16, 14, 10], dtype=int64), 24),
#  (array([14, 10, 24], dtype=int64), 10),
#  (array([10, 24, 10], dtype=int64), 20),
#  (array([24, 10, 20], dtype=int64), 10),
#  (array([10, 20, 10], dtype=int64), 26),
#  (array([20, 10, 26], dtype=int64), 25),
#  (array([10, 26, 25], dtype=int64), 16),
#  (array([26, 25, 16], dtype=int64), 19),
#  (array([25, 16, 19], dtype=int64), 20),
#  (array([16, 19, 20], dtype=int64), 12),
#  (array([19, 20, 12], dtype=int64), 19),
#  (array([20, 12, 19], dtype=int64), 50),
#  (array([12, 19, 50], dtype=int64), 16),
#  (array([19, 50, 16], dtype=int64), 30),
#  (array([50, 16, 30], dtype=int64), 18),
#  (array([16, 30, 18], dtype=int64), 25),
#  (array([30, 18, 25], dtype=int64), 14),
#  (array([18, 25, 14], dtype=int64), 20),
#  (array([25, 14, 20], dtype=int64), 8),
#  (array([14, 20,  8], dtype=int64), 67),
#  (array([20,  8, 67], dtype=int64), 13),
#  (array([ 8, 67, 13], dtype=int64), 41),
#  (array([67, 13, 41], dtype=int64), 10),
#  (array([13, 41, 10], dtype=int64), 21),
#  (array([41, 10, 21], dtype=int64), 13),
#  (array([10, 21, 13], dtype=int64), 8),
#  (array([21, 13,  8], dtype=int64), 15),
#  (array([13,  8, 15], dtype=int64), 14),
#  (array([ 8, 15, 14], dtype=int64), 12),
#  (array([15, 14, 12], dtype=int64), 6),
#  (array([14, 12,  6], dtype=int64), 11),
#  (array([12,  6, 11], dtype=int64), 10),
#  (array([ 6, 11, 10], dtype=int64), 42),
#  (array([11, 10, 42], dtype=int64), 21),
#  (array([10, 42, 21], dtype=int64), 24),
#  (array([42, 21, 24], dtype=int64), 14),
#  (array([21, 24, 14], dtype=int64), 11),
#  (array([24, 14, 11], dtype=int64), 204),
#  (array([ 14,  11, 204], dtype=int64), 14),
#  (array([ 11, 204,  14], dtype=int64), 45),
#  (array([204,  14,  45], dtype=int64), 33),
#  (array([14, 45, 33], dtype=int64), 28),
#  (array([45, 33, 28], dtype=int64), 18),
#  (array([33, 28, 18], dtype=int64), 14),
#  (array([28, 18, 14], dtype=int64), 47),
#  (array([18, 14, 47], dtype=int64), 15),
#  (array([14, 47, 15], dtype=int64), 14),
#  (array([47, 15, 14], dtype=int64), 18),
#  (array([15, 14, 18], dtype=int64), 20),
#  (array([14, 18, 20], dtype=int64), 14),
#  (array([18, 20, 14], dtype=int64), 16),
#  (array([20, 14, 16], dtype=int64), 14),
#  (array([14, 16, 14], dtype=int64), 20),
#  (array([16, 14, 20], dtype=int64), 60),
#  (array([14, 20, 60], dtype=int64), 22),
#  (array([20, 60, 22], dtype=int64), 15),
#  (array([60, 22, 15], dtype=int64), 17),
#  (array([22, 15, 17], dtype=int64), 19),
#  (array([15, 17, 19], dtype=int64), 18),
#  (array([17, 19, 18], dtype=int64), 21),
#  (array([19, 18, 21], dtype=int64), 21),
#  (array([18, 21, 21], dtype=int64), 47),
#  (array([21, 21, 47], dtype=int64), 65),
#  (array([21, 47, 65], dtype=int64), 17),
#  (array([47, 65, 17], dtype=int64), 32),
#  (array([65, 17, 32], dtype=int64), 63),
#  (array([17, 32, 63], dtype=int64), 15),
#  (array([32, 63, 15], dtype=int64), 26),
#  (array([63, 15, 26], dtype=int64), 14),
#  (array([15, 26, 14], dtype=int64), 20),
#  (array([26, 14, 20], dtype=int64), 22),
#  (array([14, 20, 22], dtype=int64), 19),
#  (array([20, 22, 19], dtype=int64), 18),
#  (array([22, 19, 18], dtype=int64), 20)]

# %%
pd.DataFrame(tuple_list, columns=['features1', 'target'])
# Out:
#         features1  target
# 0     [18, 11, 5]      13
# 1     [11, 5, 13]      14
# 2     [5, 13, 14]       9
# 3     [13, 14, 9]       9
# 4      [14, 9, 9]      22
# ..            ...     ...
# 542  [15, 26, 14]      20
# 543  [26, 14, 20]      22
# 544  [14, 20, 22]      19
# 545  [20, 22, 19]      18
# 546  [22, 19, 18]      20
#
# [547 rows x 2 columns]

# %%
feature_1 = []
feature_2 = []
feature_3 = []
for i in range(len(tuple_list)):
    feature_1 .append(tuple_list[i][0][0])
    feature_2 .append(tuple_list[i][0][1])
    feature_3 .append(tuple_list[i][0][2])
#     for j in range(3):
#         tuple_list[i][0][j]

# %%
feature_3
# Out:
# [5,
#  13,
#  14,
#  9,
#  9,
#  22,
#  26,
#  24,
#  19,
#  10,
#  14,
#  15,
#  8,
#  16,
#  8,
#  8,
#  16,
#  7,
#  11,
#  10,
#  20,
#  18,
#  15,
#  14,
#  49,
#  10,
#  16,
#  18,
#  8,
#  5,
#  9,
#  7,
#  13,
#  9,
#  7,
#  4,
#  11,
#  10,
#  5,
#  9,
#  9,
#  9,
#  9,
#  13,
#  4,
#  15,
#  25,
#  9,
#  5,
#  6,
#  20,
#  3,
#  14,
#  46,
#  5,
#  5,
#  13,
#  4,
#  9,
#  10,
#  9,
#  11,
#  11,
#  11,
#  9,
#  15,
#  5,
#  10,
#  7,
#  4,
#  8,
#  9,
#  10,
#  6,
#  13,
#  16,
#  6,
#  24,
#  9,
#  11,
#  12,
#  8,
#  14,
#  6,
#  6,
#  11,
#  14,
#  6,
#  10,
#  20,
#  7,
#  15,
#  8,
#  15,
#  5,
#  8,
#  8,
#  5,
#  11,
#  165,
#  34,
#  6,
#  13,
#  8,
#  9,
#  11,
#  26,
#  18,
#  3,
#  5,
#  12,
#  6,
#  16,
#  19,
#  9,
#  10,
#  11,
#  11,
#  7,
#  9,
#  10,
#  24,
#  6,
#  6,
#  8,
#  16,
#  13,
#  10,
#  10,
#  6,
#  5,
#  20,
#  6,
#  47,
#  9,
#  9,
#  12,
#  11,
#  17,
#  15,
#  14,
#  11,
#  97,
#  11,
#  12,
#  11,
#  14,
#  15,
#  12,
#  104,
#  5,
#  22,
#  45,
#  75,
#  29,
#  34,
#  20,
#  12,
#  25,
#  9,
#  62,
#  20,
#  19,
#  8,
#  23,
#  13,
#  16,
#  34,
#  36,
#  11,
#  18,
#  12,
#  24,
#  30,
#  27,
#  44,
#  35,
#  53,
#  11,
#  26,
#  13,
#  18,
#  9,
#  16,
#  6,
#  19,
#  20,
#  19,
#  22,
#  30,
#  14,
#  16,
#  22,
#  15,
#  15,
#  26,
#  16,
#  13,
#  27,
#  18,
#  13,
#  32,
#  31,
#  16,
#  38,
#  18,
#  9,
#  14,
#  10,
#  24,
#  8,
#  15,
#  18,
#  10,
#  23,
#  17,
#  11,
#  26,
#  14,
#  8,
#  12,
#  9,
#  11,
#  34,
#  17,
#  29,
#  11,
#  9,
#  14,
#  21,
#  12,
#  11,
#  13,
#  11,
#  13,
#  16,
#  13,
#  19,
#  21,
#  14,
#  11,
#  35,
#  18,
#  42,
#  15,
#  5,
#  21,
#  56,
#  9,
#  20,
#  17,
#  18,
#  8,
#  9,
#  17,
#  9,
#  10,
#  14,
#  17,
#  6,
#  18,
#  13,
#  11,
#  12,
#  11,
#  8,
#  15,
#  11,
#  20,
#  59,
#  11,
#  18,
#  17,
#  12,
#  14,
#  13,
#  9,
#  490,
#  189,
#  102,
#  38,
#  126,
#  71,
#  21,
#  57,
#  79,
#  17,
#  17,
#  23,
#  16,
#  23,
#  18,
#  22,
#  44,
#  6,
#  31,
#  17,
#  25,
#  40,
#  19,
#  15,
#  15,
#  29,
#  18,
#  16,
#  13,
#  20,
#  22,
#  19,
#  11,
#  50,
#  22,
#  39,
#  23,
#  21,
#  23,
#  22,
#  16,
#  19,
#  35,
#  16,
#  12,
#  15,
#  13,
#  14,
#  10,
#  21,
#  20,
#  19,
#  14,
#  12,
#  15,
#  17,
#  16,
#  21,
#  27,
#  13,
#  11,
#  15,
#  14,
#  18,
#  18,
#  10,
#  11,
#  14,
#  18,
#  14,
#  13,
#  17,
#  15,
#  14,
#  234,
#  8,
#  62,
#  26,
#  22,
#  8,
#  22,
#  15,
#  69,
#  11,
#  18,
#  23,
#  12,
#  20,
#  17,
#  15,
#  16,
#  18,
#  21,
#  15,
#  30,
#  115,
#  56,
#  45,
#  17,
#  18,
#  15,
#  18,
#  14,
#  15,
#  15,
#  24,
#  22,
#  18,
#  30,
#  12,
#  13,
#  18,
#  17,
#  31,
#  26,
#  29,
#  12,
#  19,
#  19,
#  57,
#  17,
#  20,
#  49,
#  10,
#  19,
#  26,
#  41,
#  23,
#  30,
#  55,
#  17,
#  24,
#  14,
#  12,
#  49,
#  42,
#  37,
#  13,
#  30,
#  20,
#  33,
#  20,
#  14,
#  40,
#  15,
#  18,
#  26,
#  8,
#  25,
#  21,
#  20,
#  25,
#  19,
#  23,
#  18,
#  19,
#  18,
#  55,
#  16,
#  65,
#  11,
#  11,
#  13,
#  20,
#  21,
#  13,
#  24,
#  20,
#  13,
#  32,
#  16,
#  10,
#  13,
#  44,
#  17,
#  13,
#  72,
#  40,
#  19,
#  14,
#  13,
#  12,
#  14,
#  10,
#  26,
#  13,
#  22,
#  14,
#  23,
#  12,
#  8,
#  50,
#  13,
#  10,
#  16,
#  14,
#  10,
#  24,
#  10,
#  20,
#  10,
#  26,
#  25,
#  16,
#  19,
#  20,
#  12,
#  19,
#  50,
#  16,
#  30,
#  18,
#  25,
#  14,
#  20,
#  8,
#  67,
#  13,
#  41,
#  10,
#  21,
#  13,
#  8,
#  15,
#  14,
#  12,
#  6,
#  11,
#  10,
#  42,
#  21,
#  24,
#  14,
#  11,
#  204,
#  14,
#  45,
#  33,
#  28,
#  18,
#  14,
#  47,
#  15,
#  14,
#  18,
#  20,
#  14,
#  16,
#  14,
#  20,
#  60,
#  22,
#  15,
#  17,
#  19,
#  18,
#  21,
#  21,
#  47,
#  65,
#  17,
#  32,
#  63,
#  15,
#  26,
#  14,
#  20,
#  22,
#  19,
#  18]

# %%
df_tmp = list(zip(feature_1, feature_2, feature_3, target_val))

# %%
df_tmp[:5]
# Out:
# [(18, 11, 5, 13),
#  (11, 5, 13, 14),
#  (5, 13, 14, 9),
#  (13, 14, 9, 9),
#  (14, 9, 9, 22)]

# %%
df_base = pd.DataFrame(df_tmp, columns=['var_lag3', 'var_lag2', 'var_lag1', 'current_val'])

# %%
df_base.head()
# Out:
#    var_lag3  var_lag2  var_lag1  current_val
# 0        18        11         5           13
# 1        11         5        13           14
# 2         5        13        14            9
# 3        13        14         9            9
# 4        14         9         9           22

# %%
df['date_idx'][3:]
# Out:
# 3     2015-07-04
# 4     2015-07-05
# 5     2015-07-06
# 6     2015-07-07
# 7     2015-07-08
#          ...
# 545   2016-12-27
# 546   2016-12-28
# 547   2016-12-29
# 548   2016-12-30
# 549   2016-12-31
# Name: date_idx, Length: 547, dtype: datetime64[ns]

# %%
df_base.tail()
# Out:
#      var_lag3  var_lag2  var_lag1  current_val
# 542        15        26        14           20
# 543        26        14        20           22
# 544        14        20        22           19
# 545        20        22        19           18
# 546        22        19        18           20

# %%
date_series = df['date_idx'][3:]
pd.concat([df_base, date_series], axis=1)
# Out:
#      var_lag3  var_lag2  var_lag1  current_val   date_idx
# 0        18.0      11.0       5.0         13.0        NaT
# 1        11.0       5.0      13.0         14.0        NaT
# 2         5.0      13.0      14.0          9.0        NaT
# 3        13.0      14.0       9.0          9.0 2015-07-04
# 4        14.0       9.0       9.0         22.0 2015-07-05
# ..        ...       ...       ...          ...        ...
# 545      20.0      22.0      19.0         18.0 2016-12-27
# 546      22.0      19.0      18.0         20.0 2016-12-28
# 547       NaN       NaN       NaN          NaN 2016-12-29
# 548       NaN       NaN       NaN          NaN 2016-12-30
# 549       NaN       NaN       NaN          NaN 2016-12-31
#
# [550 rows x 5 columns]

# %%
len(df_base)
# Out:
# 547

# %%
len(df['date_idx'][3:])
# Out:
# 547

# %%
df['date_idx'][3:]
# Out:
# 3     2015-07-04
# 4     2015-07-05
# 5     2015-07-06
# 6     2015-07-07
# 7     2015-07-08
#          ...
# 545   2016-12-27
# 546   2016-12-28
# 547   2016-12-29
# 548   2016-12-30
# 549   2016-12-31
# Name: date_idx, Length: 547, dtype: datetime64[ns]

# %% [markdown]
# ### As you see the date is not concatinated properly even with "ignore_index=True". This issue is explain [here](https://stackoverflow.com/questions/32801806/pandas-concat-ignore-index-doesnt-work). By reseting indices of both dataframes, this can be resolved as follows:

# %%
date_series.reset_index(drop=True, inplace=True)

# %%
df_base.reset_index(drop=True, inplace=True)

# %%
df_base_features = pd.concat([df_base, date_series], axis=1)
df_base_features
# Out:
#      var_lag3  var_lag2  var_lag1  current_val   date_idx
# 0          18        11         5           13 2015-07-04
# 1          11         5        13           14 2015-07-05
# 2           5        13        14            9 2015-07-06
# 3          13        14         9            9 2015-07-07
# 4          14         9         9           22 2015-07-08
# ..        ...       ...       ...          ...        ...
# 542        15        26        14           20 2016-12-27
# 543        26        14        20           22 2016-12-28
# 544        14        20        22           19 2016-12-29
# 545        20        22        19           18 2016-12-30
# 546        22        19        18           20 2016-12-31
#
# [547 rows x 5 columns]

# %%
columns_to_keep = ['var_lag1', 'var_lag2', 'var_lag3']
df_base_features[columns_to_keep].mean(axis=1)
# Out:
# 0      11.333333
# 1       9.666667
# 2      10.666667
# 3      12.000000
# 4      10.666667
#          ...
# 542    18.333333
# 543    20.000000
# 544    18.666667
# 545    20.333333
# 546    19.666667
# Length: 547, dtype: float64

# %%
columns_to_keep = ['var_lag1', 'var_lag2', 'var_lag3']
df_base_features['mean'] = df_base_features[columns_to_keep].mean(axis=1).apply(lambda x: round(x, 2))

# %%
df_base_features.head()
# Out:
#    var_lag3  var_lag2  var_lag1  current_val   date_idx   mean
# 0        18        11         5           13 2015-07-04  11.33
# 1        11         5        13           14 2015-07-05   9.67
# 2         5        13        14            9 2015-07-06  10.67
# 3        13        14         9            9 2015-07-07  12.00
# 4        14         9         9           22 2015-07-08  10.67

# %%
columns_to_keep = ['var_lag1', 'var_lag2', 'var_lag3']
df_base_features['std'] = df_base_features[columns_to_keep].std(axis=1).apply(lambda x: round(x, 2))

# %%
df_base_features['diff1'] = df_base_features['current_val'] - df_base_features['var_lag1']
df_base_features['diff2'] = df_base_features['current_val'] - df_base_features['var_lag2']
df_base_features['diff3'] = df_base_features['current_val'] - df_base_features['var_lag3']

# %%
df_base_features
# Out:
#      var_lag3  var_lag2  var_lag1  current_val   date_idx   mean   std  diff1  \
# 0          18        11         5           13 2015-07-04  11.33  6.51      8
# 1          11         5        13           14 2015-07-05   9.67  4.16      1
# 2           5        13        14            9 2015-07-06  10.67  4.93     -5
# 3          13        14         9            9 2015-07-07  12.00  2.65      0
# 4          14         9         9           22 2015-07-08  10.67  2.89     13
# ..        ...       ...       ...          ...        ...    ...   ...    ...
# 542        15        26        14           20 2016-12-27  18.33  6.66      6
# 543        26        14        20           22 2016-12-28  20.00  6.00      2
# 544        14        20        22           19 2016-12-29  18.67  4.16     -3
# 545        20        22        19           18 2016-12-30  20.33  1.53     -1
# 546        22        19        18           20 2016-12-31  19.67  2.08      2
#
#      diff2  diff3
# 0        2     -5
# 1        9      3
# 2       -4      4
# 3       -5     -4
# 4       13      8
# ..     ...    ...
# 542     -6      5
# 543      8     -4
# 544     -1      5
# 545     -4     -2
# 546      1     -2
#
# [547 rows x 10 columns]

# %% [markdown]
# ### Applying XGBoost to above dataframe
#
# Now that we have created features and prepared our dataframe, we use different models to predict values. As the number of data is only 547 records, lightgbm and catboost are probably not suitable.

# %%
# ! conda install -c anaconda py-xgboost

# Specifications: - py-xgboost -> python[version='>=2.7,<2.8.0a0|>=3.6,<3.7.0a0|>=3.7,<3.8.0a0|>=3.5,<3.6.0a0']

# %%
from xgboost import XGBRegressor

# %%
df_base_features.dtypes
# Out:
# var_lag3                int64
# var_lag2                int64
# var_lag1                int64
# current_val             int64
# date_idx       datetime64[ns]
# mean                  float64
# std                   float64
# diff1                   int64
# diff2                   int64
# diff3                   int64
# dtype: object

# %%
df_base_features.isnull().any()
# Out:
# var_lag3       False
# var_lag2       False
# var_lag1       False
# current_val    False
# date_idx       False
# mean           False
# std            False
# diff1          False
# diff2          False
# diff3          False
# dtype: bool

# %%
X = df_base_features.drop('current_val', axis = 1)
X = X.drop('date_idx', axis = 1)
y = df_base_features['current_val']

# %%
X.isnull().any()
# Out:
# var_lag3    False
# var_lag2    False
# var_lag1    False
# mean        False
# std         False
# diff1       False
# diff2       False
# diff3       False
# dtype: bool

# %%
y.isnull().any()
# Out:
# False

# %%
seed = 2021
test_size = 0.1
train_len = round(len(df_base_features) * (1-test_size))
X_train = X[:train_len]
X_test = X[train_len:]
y_train = y[:train_len]
y_test = y[train_len:]
# X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=test_size, random_state = seed)
# # preparing validation set
# X_test, X_val, y_test, y_val = train_test_split(X_test, y_test, test_size=.5)

# # fit model on training data
xgb_model = XGBRegressor(random_state=seed, n_estimators=2000, max_depth=4, colsample_bytree=0.85, missing=None,
                         scale_pos_weight=0.1, learning_rate=0.008, reg_alpha=2.01, reg_lambda=0.05, verbosity=1)
xgb_model.fit(X_train, y_train, verbose=150 )
# Out:
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=0.85, gamma=0, gpu_id=-1,
#              importance_type='gain', interaction_constraints='',
#              learning_rate=0.008, max_delta_step=0, max_depth=4,
#              min_child_weight=1, missing=None, monotone_constraints='()',
#              n_estimators=2000, n_jobs=8, num_parallel_tree=1,
#              random_state=2021, reg_alpha=2.01, reg_lambda=0.05,
#              scale_pos_weight=0.1, subsample=1, tree_method='exact',
#              validate_parameters=1, verbosity=1)

# %%
predictions_xgb = xgb_model.predict(X_test)
predictions_xgb
# Out:
# array([ 63.37521 ,  12.908805,  50.88125 ,  11.950102,  19.544756,
#         13.738129,   8.444078,  15.292019,  14.045978,  12.74824 ,
#          5.706309,  11.991892,  10.426684,  43.940742,  22.775871,
#         23.685684,  14.610772,  10.765169, 253.27005 ,  13.651187,
#         54.065205,  25.695747,  25.73571 ,  15.390067,  13.693675,
#         47.669296,  14.189787,  13.761846,  18.205252,  19.316801,
#         12.83852 ,  15.052923,  14.481504,  20.554176,  59.55235 ,
#         20.370491,  14.518354,  15.712749,  18.503553,  17.410868,
#         21.03111 ,  18.800829,  52.73854 ,  58.75331 ,  14.27705 ,
#         27.686716,  57.4965  ,  14.114   ,  23.331219,  14.216544,
#         20.799997,  21.33165 ,  18.886366,  17.40021 ,  19.257027],
#       dtype=float32)

# %%
xgb_model.score(X_test, y_test)
# Out:
# 0.9350600529668849

# %%
xgb_model.score(X_train, y_train)
# Out:
# 0.9997910522430393

# %%
from sklearn.metrics import accuracy_score

# %%
# accuracy_score(y_test, predictions_xgb)

# accuracy_score is for classification problem and not regressor. If you try it, not only it is wrong, but also
# you will get the following error:
# ValueError: Classification metrics can't handle a mix of multiclass and continuous targets
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-56-fa26d5feca69> in <module>
# ----> 1 accuracy_score(y_test, predictions_xgb)
#
# ~\Anaconda3\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      71                           FutureWarning)
#      72         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 73         return f(**kwargs)
#      74     return inner_f
#      75
#
# ~\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py in accuracy_score(y_true, y_pred, normalize, sample_weight)
#     185
#     186     # Compute accuracy for each possible representation
# --> 187     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#     188     check_consistent_length(y_true, y_pred, sample_weight)
#     189     if y_type.startswith('multilabel'):
#
# ~\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py in _check_targets(y_true, y_pred)
#      88
#      89     if len(y_type) > 1:
# ---> 90         raise ValueError("Classification metrics can't handle a mix of {0} "
#      91                          "and {1} targets".format(type_true, type_pred))
#      92
#
# ValueError: Classification metrics can't handle a mix of multiclass and continuous targets
